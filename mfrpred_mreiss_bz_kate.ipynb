# %% [markdown]
# ### Machine learning for predicting the magnetic flux rope structure in coronal mass ejections (Bz)
#
# Coronal mass ejections continually interact with Earth's space weather environment driving geomagnetic storm activity. The severity of geomagnetic storms is determined by the magnetic flux rope structure in the coronal mass ejections. Predicting the flux rope structure is however an open question in the community. Here we study if the in situ signature in the sheath region contains sufficient information for predicting the magnetic flux rope field in coronal mass ejections. Further, we quantify how much time is needed inside the flux rope to predict the mean total magnetic field of the flux rope with high accuracy. To do so, we use widely-applied machine learning algorithms such as linear regression, lars lasso, and random forest. We train, test, and validate these algorithms on coronal mass ejections in retrospective real-time mode for the Wind, Stereo-A, and Stereo-B mission data in the HELCATS CME catalog.
#
# #### Contributors:
# M.A. Reiss, C. Möstl, R.L. Bailey, and U. Amerstorfer (Space Research Institute IWF, Graz, Austria)
#
# #### Solar wind data:
# Copy Version 8 from https://figshare.com/articles/dataset/Solar_wind_in_situ_data_suitable_for_machine_learning_python_numpy_arrays_STEREO-A_B_Wind_Parker_Solar_Probe_Ulysses_Venus_Express_MESSENGER/12058065
# into folder /data.

# %%
# Python Modules and Packages
import os
import sys
import matplotlib.pyplot as plt
from matplotlib.dates import date2num, num2date
from matplotlib import cm
import numpy as np
import pickle
from scipy import stats
import scipy.io
import time

# Visualisation
import sunpy.time
import seaborn as sns
import pandas as pd
from pandas.plotting import scatter_matrix
from sunpy.time import parse_time

# Machine learning
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, median_absolute_error, r2_score
from sklearn.feature_selection import SelectKBest, SelectPercentile, f_classif
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.linear_model import ElasticNet, HuberRegressor, Lars, LassoLars
from sklearn.linear_model import PassiveAggressiveRegressor, RANSACRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

# Don't print warnings
import warnings
warnings.filterwarnings('ignore')

# Print versions
print('Current Versions')
import matplotlib
print(np.__version__)#==1.17.2
print(matplotlib.__version__)#3.1.2
print(scipy.__version__)#1.3.1
print(pd.__version__)#0.25.3
import sklearn
print(sklearn.__version__)#0.20.3
print(sns.__version__)#0.9.0
import PIL
print(PIL.__version__)#8.1.2

os.system('jupyter nbconvert --to script mfrpred_mreiss_bz.ipynb')
# Out:
# Current Versions
# 1.19.5
# 3.2.2
# 1.4.1
# 1.1.5
# 0.22.2.post1
# 0.11.1
# 7.1.2
# 65280

# %%
# !pip install sunpy

# %% [markdown]
# ## 1. Data preparation

# %% [markdown]
# #### File and folder variables:

# %%
# Make plots and results folders
mfrdir = 'mfr_predict'
if os.path.isdir(mfrdir) == False: 
    os.mkdir(mfrdir)

plotdir = 'plots'
if os.path.isdir(plotdir) == False: 
    os.mkdir(plotdir)
    
# File names to save features into
savepath_win = 'wind_features.p'
savepath_sta = 'sta_features.p'
savepath_stb = 'stb_features.p'

# %% [markdown]
# #### Load HELCATS ICME data catalog

# %%
[ic,header,parameters] = pickle.load(open('data/HELCATS_ICMECAT_v20_pandas.p', "rb" ))

# Spacecraft
isc = ic.loc[:,'sc_insitu'] 

# Shock arrival or density enhancement time
icme_start_time = ic.loc[:,'icme_start_time']
icme_start_time_num = date2num(np.array(icme_start_time))

# Start time of the magnetic obstacle (mo)
mo_start_time = ic.loc[:,'mo_start_time']
mo_start_time_num = date2num(np.array(mo_start_time))

# End time of the magnetic obstacle (mo)
mo_end_time = ic.loc[:,'mo_end_time']
mo_end_time_num = date2num(np.array(mo_end_time))

#get indices for each target
wini=np.where(ic.sc_insitu=='Wind')[0]
stai=np.where(ic.sc_insitu=='STEREO-A')[0]
stbi=np.where(ic.sc_insitu=='STEREO-B')[0]
pspi=np.where(ic.sc_insitu=='PSP')[0]
soloi=np.where(ic.sc_insitu=='SolarOrbiter')[0]
bepii=np.where(ic.sc_insitu=='BepiColombo')[0]
ulyi=np.where(ic.sc_insitu=='Ulysses')[0]
messi=np.where(ic.sc_insitu=='Messenger')[0]
vexi=np.where(ic.sc_insitu=='VEX')[0]

# %% [markdown]
# #### Load spacecraft data

# %%
# Load Wind data
[win, winheader] = pickle.load(open("data/wind_2007_2021_heeq_ndarray.p", "rb"))

# Load STEREO-A data
[sta, atta] = pickle.load(open("data/stereoa_2007_2021_sceq_ndarray.p", "rb"))

# Load STEREO-B data
[stb, attb, stbheader] = pickle.load(open("data/stereob_2007_2014_sceq_ndarray.p", "rb"))

# %% [markdown]
# #### Study only events with a sheath region

# %%
# Event indices from STEREO and Wind
istaind = np.where(isc == 'STEREO-A')[0]
istbind = np.where(isc == 'STEREO-B')[0]
iwinind = np.where(isc == 'Wind')[0]

# Event indices where the start time of the CME does not match the start time of the magnetic obstacle
n_iwinind = np.where(icme_start_time_num[iwinind] != mo_start_time_num[iwinind])[0]
n_istaind = np.where(icme_start_time_num[istaind] != mo_start_time_num[istaind])[0]
n_istbind = np.where(icme_start_time_num[istbind] != mo_start_time_num[istbind])[0]

# Correct indicies to take from all data, not just subset
i_icme_start_time_num = np.arange(len(icme_start_time_num))
n_iwinind = i_icme_start_time_num[iwinind][n_iwinind]
n_istaind = i_icme_start_time_num[istaind][n_istaind]
n_istbind = i_icme_start_time_num[istbind][n_istbind]

# Count the number of selected events
print("Events with a sheath region in WIND    : {} / {}".format(n_iwinind.shape[0], iwinind.shape[0]))   # TODO
print("Events with a sheath region in STEREO-A: {} / {}".format(n_istaind.shape[0], istaind.shape[0]))
print("Events with a sheath region in STEREO-B: {} / {}".format(n_istbind.shape[0], istbind.shape[0]))
print("Number of Events with a sheath region  :", n_iwinind.shape[0] + n_istaind.shape[0] + n_istbind.shape[0])
print('Percentage of all events',np.round((n_iwinind.shape[0] + n_istaind.shape[0] + n_istbind.shape[0])/ (np.size(stbi)+np.size(wini)+np.size(stai))*100))

# Indices of all selected events
#n_all1=np.hstack([n_iwinind,n_istaind,n_istbind])
# Out:
# Events with a sheath region in WIND    : 149 / 186
# Events with a sheath region in STEREO-A: 135 / 222
# Events with a sheath region in STEREO-B: 78 / 150
# Number of Events with a sheath region  : 362
# Percentage of all events 65.0

# %% [markdown]
# #### Timing windows for features and labels

# %%
# Set time window for features in hours
feature_hours = 4 #10

# Decide if you want to include the sheath region. 
use_sheath = True

if use_sheath:
    print("Option 1: Use MFR and sheath data for features")
    event_start = icme_start_time_num
else:
    print("Option 2: Use MFR and no sheath data for features")
    event_start = mo_start_time_num

# Define end of the event time window
event_end = mo_start_time_num + feature_hours / 24.0
      
# Define timing window of labels
label_start = mo_start_time_num
label_end = mo_end_time_num
# Out:
# Option 1: Use MFR and sheath data for features

# %% [markdown]
# #### Functions to compute features and labels

# %%
# Compute mean, max and std-dev in feature time window
def get_feature(name, sc_time, start_time, end_time, sc_ind, sc_feature):
    feature_mean = np.zeros(np.size(sc_ind))
    feature_max = np.zeros(np.size(sc_ind))
    feature_std = np.zeros(np.size(sc_ind))
    feature_min = np.zeros(np.size(sc_ind))
    feature_cv  = np.zeros(np.size(sc_ind))
    feature_minmax = np.zeros(np.size(sc_ind))
    
    for p in np.arange(0, np.size(sc_ind)):
        time_slice = np.where(np.logical_and(sc_time > start_time[sc_ind[p]], sc_time < end_time[sc_ind[p]]))
        feature_slice = sc_feature[time_slice]
        feature_mean[p] = np.nanmean(feature_slice)
        feature_std[p] = np.nanstd(feature_slice)
        
        # Compute coefficient of variation (CV)
        feature_cv[p] = feature_std[p]/np.abs(feature_mean[p])
        
        feature_temp = feature_slice[np.isfinite(feature_slice)]
        
        #save indices of selected events
        if name=='win': win_select_ind.append(sc_ind[p])              
        if name=='sta': sta_select_ind.append(sc_ind[p])
        if name=='stb': stb_select_ind.append(sc_ind[p])
        
        try:
            feature_max[p] = np.max(feature_temp)
            feature_min[p] = np.min(feature_temp)
            feature_minmax[p] = feature_min[p]/feature_max[p]
        except ValueError:  # raised if `y` is empty.
            pass

    return feature_mean, feature_max, feature_std, feature_min, feature_cv, feature_minmax

# Compute either 'max' or 'mean' of total magnetic field in label time window
def get_label(sc_time, start_time, end_time, sc_ind, sc_label, label_type="max"):
    label_mean = np.zeros(np.size(sc_ind))
    label_max = np.zeros(np.size(sc_ind))
    label_min = np.zeros(np.size(sc_ind))

    for p in np.arange(0, np.size(sc_ind)):
        time_slice = np.where(np.logical_and(sc_time > start_time[sc_ind[p]], sc_time < end_time[sc_ind[p]]))
        label_slice = sc_label[time_slice]
        if len(label_slice) == 0:
            label_max[p] = np.nan
            label_min[p] = np.nan
            label_mean[p] = np.nan
        else:
            label_max[p] = np.nanmax(label_slice)
            label_min[p] = np.min([np.nanmin(label_slice), 0])
            label_mean[p] = np.nanmean(label_slice)
            
    if label_type == 'max':
        return label_max
    elif label_type == 'min':
        return label_min
    elif label_type == 'mean':
        return label_mean

# %% [markdown]
# #### Create data frame for features and labels

# %%
#contains all events that are finally selected
win_select_ind=[]
sta_select_ind=[]
stb_select_ind=[]


# Compute either 'max' or 'mean' of total magnetic field in label time window
target_type = 'min'

# List of physical properties
variable_list = ['bx', 'by', 'bz', 'bt', 'vt','np','tp']


# If file doesn't exist, create it, otherwise load it
if not os.path.exists("mfr_predict/bz_fh{:.0f}_sta_features.p".format(feature_hours)):
    start_time = time.time()
    print("Option 1: Compute features...")

    # Wind features
    dwin = {}
    for variable in variable_list:
        all_var_features = get_feature('win',win['time'], event_start, event_end, n_iwinind, win[variable])
        dwin['mean('+variable+')'] = all_var_features[0]
        dwin['max('+variable+')'] = all_var_features[1]
        dwin['std('+variable+')'] = all_var_features[2]
        dwin['min('+variable+')'] = all_var_features[3]
        dwin['cv('+variable+')'] = all_var_features[4]
        dwin['minmax('+variable+')'] = all_var_features[5]

    # Wind labels
    label_btotmean = get_label(win['time'], label_start, label_end, n_iwinind, win['bz'], label_type=target_type)
    dwin['Target'] = label_btotmean
    
    # Create dataframe
    dfwin = pd.DataFrame(data=dwin)
    pickle.dump(dfwin, open(os.path.join(mfrdir, 'bz_fh{:.0f}_'.format(feature_hours) + savepath_win), "wb"))
    
    #dump original indices
    win_select_size=int(len(win_select_ind)/len(variable_list))
    win_select_ind=win_select_ind[0:win_select_size]
    pickle.dump(win_select_ind, open(os.path.join(mfrdir, 'bz_orig_ind_' + savepath_win), "wb"))
    
    ################### STEREO-A features
    dsta = {}
    for variable in variable_list:
        all_var_features = get_feature('sta',sta['time'], event_start, event_end, 
                                       n_istaind, sta[variable])
        dsta['mean('+variable+')'] = all_var_features[0]
        dsta['max('+variable+')'] = all_var_features[1]
        dsta['std('+variable+')'] = all_var_features[2]
        dsta['min('+variable+')'] = all_var_features[3]
        dsta['cv('+variable+')'] = all_var_features[4]
        dsta['minmax('+variable+')'] = all_var_features[5]

    # STEREO-A labels
    label_btotmean = get_label(sta['time'], label_start, label_end, n_istaind, sta['bz'], label_type=target_type)
    dsta['Target'] = label_btotmean
    
    # Create dateframe
    dfsta = pd.DataFrame(data=dsta)
    pickle.dump(dfsta, open(os.path.join(mfrdir, 'bz_fh{:.0f}_'.format(feature_hours) + savepath_sta), "wb"))
    
    #dump original indices
    sta_select_size=int(len(sta_select_ind)/len(variable_list))
    sta_select_ind=sta_select_ind[0:sta_select_size]
    pickle.dump(sta_select_ind, open(os.path.join(mfrdir, 'bz_orig_ind_' + savepath_sta), "wb"))


    
    #################### STEREO-B features
    dstb = {}
    for variable in variable_list:
        all_var_features = get_feature('stb',stb['time'], event_start, event_end, 
                                       n_istbind, stb[variable])
        dstb['mean('+variable+')'] = all_var_features[0]
        dstb['max('+variable+')'] = all_var_features[1]
        dstb['std('+variable+')'] = all_var_features[2]
        dstb['min('+variable+')'] = all_var_features[3]
        dstb['cv('+variable+')'] = all_var_features[4]
        dstb['minmax('+variable+')'] = all_var_features[5]

    # STEREO-B labels
    label_btotmean = get_label(stb['time'], label_start, label_end, n_istbind, stb['bz'], label_type=target_type)
    dstb['Target'] = label_btotmean
    
    # Create dataframe
    dfstb = pd.DataFrame(data=dstb)
    pickle.dump(dfstb, open(os.path.join(mfrdir, 'bz_fh{:.0f}_'.format(feature_hours) + savepath_stb), "wb"))

    #dump original indices
    stb_select_size=int(len(stb_select_ind)/len(variable_list))
    stb_select_ind=stb_select_ind[0:stb_select_size]
    pickle.dump(stb_select_ind, open(os.path.join(mfrdir, 'bz_orig_ind_' + savepath_stb), "wb"))

   
    
    print("Option 1: Computation of data frame for Wind, STEREO-A, and STEREO-B completed")   
    end_time = time.time()
    print("Computation of features took {:.1f} minutes.".format((end_time - start_time)/60.))
else:
    print("Option 2: Loading existing data frames...")
    dfwin = pickle.load(open(os.path.join(mfrdir, 'bz_fh{:.0f}_'.format(feature_hours) + savepath_win), "rb"))
    dfsta = pickle.load(open(os.path.join(mfrdir, 'bz_fh{:.0f}_'.format(feature_hours) + savepath_sta), "rb"))
    dfstb = pickle.load(open(os.path.join(mfrdir, 'bz_fh{:.0f}_'.format(feature_hours) + savepath_stb), "rb"))
    print("Option 2: Loading existing data frame completed")
# Out:
# Option 1: Compute features...
# Option 1: Computation of data frame for Wind, STEREO-A, and STEREO-B completed
# Computation of features took 5.8 minutes.

# %% [markdown]
# #### Clean the data frame by removing NaNs

# %%
#get original indices of the 362 events

win_select_ind = pickle.load(open(os.path.join(mfrdir, 'bz_orig_ind_' + savepath_win), "rb"))
sta_select_ind= pickle.load(open(os.path.join(mfrdir, 'bz_orig_ind_' + savepath_sta), "rb"))
stb_select_ind = pickle.load(open(os.path.join(mfrdir, 'bz_orig_ind_' + savepath_stb), "rb"))


win_select_ind=np.array(win_select_ind)
sta_select_ind=np.array(sta_select_ind)
stb_select_ind=np.array(stb_select_ind)

print(len(dfwin)+len(dfsta)+len(dfstb))
print(len(win_select_ind)+len(sta_select_ind)+len(stb_select_ind))
# Out:
# 362
# 362

# %%
print(len(dfwin))
print(len(dfsta))
print(len(dfstb))


# Events before tidying up
len_dfwin_nans = len(dfwin)
len_dfsta_nans = len(dfsta)
len_dfstb_nans = len(dfstb)

print("Total number of events  ", len(dfwin)+len(dfsta)+len(dfstb))
print()

# Remove NaN's in data frames
dfwin1 = dfwin.dropna()
dfsta1 = dfsta.dropna()
dfstb1 = dfstb.dropna()

#get indices of nans
win_nan=np.array(dfwin[dfwin.isna().any(axis=1)].index)
sta_nan=np.array(dfsta[dfsta.isna().any(axis=1)].index)
stb_nan=np.array(dfstb[dfstb.isna().any(axis=1)].index)

win_select_ind1=np.delete(win_select_ind,win_nan)
sta_select_ind1=np.delete(sta_select_ind,sta_nan)
stb_select_ind1=np.delete(stb_select_ind,stb_nan)

print(len(dfwin1), len(win_select_ind1))
print(len(dfsta1),len(sta_select_ind1))
print(len(dfstb1),len(stb_select_ind1))


print("{} nans removed from WIND data".format(len_dfwin_nans-len(dfwin1)))
print("{} nans removed from STEREO-A data".format(len_dfsta_nans-len(dfsta1)))
print("{} nans removed from STEREO-B data".format(len_dfstb_nans-len(dfstb1)))
print("Total number of events left:  ", len(dfwin1)+len(dfsta1)+len(dfstb1))

#n_all are now the indices of all 348 selected events in the ICMECAT
n_all=np.hstack([win_select_ind1,sta_select_ind1,stb_select_ind1])
print(len(n_all))
# Out:
# 149
# 135
# 78
# Total number of events   362
#
# 149 149
# 123 123
# 76 76
# 0 nans removed from WIND data
# 12 nans removed from STEREO-A data
# 2 nans removed from STEREO-B data
# Total number of events left:   348
# 348

# %%
##reduce dataframes finally to selected events
dfwin=dfwin1
dfsta=dfsta1
dfstb=dfstb1

# %% [markdown]
# ## Figure 1: ICME catalog

# %%
#markersize
ms=25
#alpha
al=0.9

sns.set_context("talk")     
sns.set_style('darkgrid')

fig=plt.figure(figsize=(20,8),dpi=100)
ax1 = plt.subplot(121) 
ax1.scatter(ic.loc[win_select_ind1,'icme_start_time'], ic.loc[win_select_ind1,'mo_sc_heliodistance'], label='Wind', s=ms,c='mediumseagreen', alpha=al)
ax1.scatter(ic.loc[sta_select_ind1,'icme_start_time'], ic.loc[sta_select_ind1,'mo_sc_heliodistance'], label='STEREO-A',s=ms,c='tomato', alpha=al)
ax1.scatter(ic.loc[stb_select_ind1,'icme_start_time'], ic.loc[stb_select_ind1,'mo_sc_heliodistance'], label='STEREO-B',s=ms,c='mediumslateblue', alpha=al)
plt.ylabel('Heliocentric Distance [AU]')
plt.xlabel('Date [years]')
plt.ylim([0.94,1.1])
plt.legend(loc=1,fontsize=13)


ax2 = plt.subplot(122) 
#ax2.scatter(ic.loc[wini,'mo_sc_heliodistance'],ic.loc[wini,'mo_bmean'], label='Wind', s=ms,c='mediumseagreen', alpha=al)
#ax2.scatter(ic.loc[stai,'mo_sc_heliodistance'],ic.loc[stai,'mo_bmean'], label='STEREO-A',s=ms,c='red', alpha=al)
#ax2.scatter(ic.loc[stbi,'mo_sc_heliodistance'],ic.loc[stbi,'mo_bmean'], label='STEREO-B',s=ms,c='blue', alpha=al)
ax2.scatter(ic.loc[win_select_ind1,'icme_start_time'],ic.loc[win_select_ind1,'mo_bmax'], label='max($B_t$) in Wind', s=ms,c='mediumseagreen', alpha=al)
ax2.scatter(ic.loc[sta_select_ind1,'icme_start_time'],ic.loc[sta_select_ind1,'mo_bmax'], label='max($B_t$) in STEREO-A',s=ms,c='tomato', alpha=al)
ax2.scatter(ic.loc[stb_select_ind1,'icme_start_time'],ic.loc[stb_select_ind1,'mo_bmax'], label='max($B_t$) in STEREO-B',s=ms,c='mediumslateblue', alpha=al)
ax2 = plt.subplot(122) 

al=1.0
ax2.scatter(ic.loc[win_select_ind1,'icme_start_time'],ic.loc[win_select_ind1,'mo_bzmin'], linestyle='None',marker='o',s=ms,edgecolors='mediumseagreen',facecolors='white',label='min($B_{\mathrm{z}}$) in Wind', alpha=al)
ax2.scatter(ic.loc[sta_select_ind1,'icme_start_time'],ic.loc[sta_select_ind1,'mo_bzmin'], linestyle='None',marker='o',s=ms,label='min($B_{\mathrm{z}}$) in STEREO-A',facecolors='white',edgecolors='tomato', alpha=al)
ax2.scatter(ic.loc[stb_select_ind1,'icme_start_time'],ic.loc[stb_select_ind1,'mo_bzmin'], linestyle='None',marker='o',s=ms,label='min($B_{\mathrm{z}}$) in STEREO-B',facecolors='white',edgecolors='mediumslateblue', alpha=al)
plt.xlabel('Date [years]')
ax2.set_ylabel('Magnetic Field Strength in MO [nT]')
ax2.legend(loc=1,fontsize=12)

# Add labels to plots
for ax, ann in zip([ax1, ax2], ['a', 'b']):
    ax.text(0.03, .93, ann, transform=ax.transAxes, fontsize=20, weight='bold')

#for ax, ann in zip([ax1, ax2], ['a', 'b']):
#    ax.text(0.02, .93, ann, transform=ax.transAxes, fontsize=32, weight='bold')
argv3 ='fig1_icmecat.pdf'
plt.savefig('plots/' + argv3, bbox_inches='tight')
argv3 ='fig1_icmecat.png'
plt.savefig('plots/' + argv3, bbox_inches='tight')
plt.show()

print('Selected events with sheath:')
print('Number of events: Wind, ',np.size(win_select_ind1))
print('Number of events: STA, ',np.size(sta_select_ind1))
print('Number of events: STB, ',np.size(stb_select_ind1))
print('Total:',np.size(win_select_ind1)+np.size(sta_select_ind1)+np.size(stb_select_ind1))
# Out:
# Selected events with sheath:
# Number of events: Wind,  149
# Number of events: STA,  123
# Number of events: STB,  76
# Total: 348

# %% [markdown]
# ## Figure 2: Parameter distribution plot

# %%
sns.set_context("talk")     
sns.set_style('whitegrid')

fig=plt.figure(figsize=(15,10),dpi=75)

fs=15
ax1 = plt.subplot(221) 
sns.histplot(ic.loc[n_all,'mo_bmean'], label='<$B_t$> in MO',color='coral',alpha=0.5,kde=True,stat='probability',element='step')
sns.histplot(ic.loc[n_all,'mo_bmax'], label='max($B_t$) in MO',color='steelblue',kde=True,stat='probability', element='step')
ax1.set_xlabel('B [nT]')
ax1.set_ylim(0,0.21)
plt.legend(loc=1,fontsize=fs)

ax2 = plt.subplot(222) 
sns.histplot(ic.loc[n_all,'mo_bzmean'],label='<$B_z$> in MO',color='coral',alpha=0.5,kde=True,stat='probability', element='step')
sns.histplot(ic.loc[n_all,'mo_bzmin'],label='min($B_z$) in MO',color='steelblue',kde=True,stat='probability', element='step')
ax2.set_xlabel('B [nT]')
#ax2.set_ylabel('')
ax2.set_ylim(0,0.21)
plt.legend(loc=2,fontsize=fs)

ax3 = plt.subplot(223) 
sns.histplot(ic.loc[n_all,'icme_speed_mean'],label='<$V_t$> in ICME',color='steelblue',kde=True,stat='probability', element='step')
ax3.set_xlabel('V [km s$^{-1}$]')
ax3.set_ylim(0,0.21)
plt.legend(loc=1,fontsize=fs)

ax4 = plt.subplot(224) 
sns.histplot(ic.loc[n_all,'icme_duration']-ic.loc[n_iwinind,'mo_duration'],label='Sheath duration',color='steelblue',kde=True,stat='probability', element='step')
sns.histplot(ic.loc[n_all,'mo_duration'],label='MO duration',color='coral',kde=True,stat='probability', element='step')
ax4.set_xlabel('hours')
ax4.set_ylim(0,0.26)
ax4.set_xlim(0,75)
#ax4.set_ylabel('')
plt.legend(loc=1,fontsize=fs)

#ax4 = plt.subplot(234) 
#sns.histplot(ic.loc[n_iwinind,'mo_density_mean'],label='MO <$N_p$>',color='steelblue',kde=True,stat='probability', element='step')
#ax4.set_xlabel('N [ccm$^{-3}$]')#
#ax4.set_ylim(0,0.25)
#ax4.set_ylabel('')
#plt.legend(loc=1)

#ax5 = plt.subplot(235) 
#sns.histplot(ic.loc[n_iwinind,'mo_temperature_mean'],label='MO <$T_p$>',color='steelblue',kde=True,stat='probability', element='step')
#ax5.set_xlabel('hours')
#ax5.set_ylim(0,0.25)#
#ax5.set_ylabel('')
#plt.legend(loc=1)
#plt.tight_layout()

plt.tight_layout()

# Add labels to plots
for ax, ann in zip([ax1, ax2, ax3, ax4], ['a', 'b','c','d']):
    ax.text(-0.17, .93, ann, transform=ax.transAxes, fontsize=26, weight='bold')

argv3 ='fig2_dist.pdf'
plt.savefig('plots/' + argv3)
argv3 ='fig2_dist.png'
plt.savefig('plots/' + argv3)

# %%
print('Statistics for the final '+str(len(n_all))+' selected events with sheath:')
print()
print("Average ICME length   : {:.2f} hours".format(((mo_end_time_num[n_all] - icme_start_time_num[n_all])*24.).mean()))
print("Average MO length     : {:.2f} hours".format(((mo_end_time_num[n_all] - mo_start_time_num[n_all])*24.).mean()))
print("Average SHEATH length : {:.2f} hours".format(((mo_start_time_num[n_all] - icme_start_time_num[n_all])*24.).mean()))
print()
print("STD ICME length       : {:.2f} hours".format(((mo_end_time_num[n_all] - icme_start_time_num[n_all])*24.).std()))
print("STD MO length         : {:.2f} hours".format(((mo_end_time_num[n_all] - mo_start_time_num[n_all])*24.).std()))
print("STD SHEATH length     : {:.2f} hours".format(((mo_start_time_num[n_all] - icme_start_time_num[n_all])*24.).std()))

print()
print("Average MO Bt max   : {:.2f} nT".format((ic.loc[n_all,'mo_bmax'].mean())))
print("std MO Bt max   : {:.2f} nT".format((ic.loc[n_all,'mo_bmax'].std())))
print()

print("Average MO Bt   : {:.2f} nT".format((ic.loc[n_all,'mo_bmean'].mean())))
print("std MO Bt   : {:.2f} nT".format((ic.loc[n_all,'mo_bmean'].std())))
print()
print("Average MO Bz   : {:.2f} nT".format((ic.loc[n_all,'mo_bzmean'].mean())))
print("std MO Bz   : {:.2f} nT".format((ic.loc[n_all,'mo_bzmean'].std())))
print()
print("Average MO Bzmin   : {:.2f} nT".format((ic.loc[n_all,'mo_bzmin'].mean())))
print("std MO Bzmin   : {:.2f} nT".format((ic.loc[n_all,'mo_bzmin'].std())))

#print("Average SHEATH length : {:.2f} hours".format(((mo_start_time_num[n_all] - icme_start_time_num[n_all])*24.).mean()))
print()
# Out:
# Statistics for the final 348 selected events with sheath:
#
# Average ICME length   : 34.26 hours
# Average MO length     : 25.24 hours
# Average SHEATH length : 9.02 hours
#
# STD ICME length       : 17.02 hours
# STD MO length         : 14.60 hours
# STD SHEATH length     : 6.02 hours
#
# Average MO Bt max   : 14.32 nT
# std MO Bt max   : 7.57 nT
#
# Average MO Bt   : 9.95 nT
# std MO Bt   : 4.47 nT
#
# Average MO Bz   : -0.32 nT
# std MO Bz   : 4.65 nT
#
# Average MO Bzmin   : -9.43 nT
# std MO Bzmin   : 6.79 nT

# %%
"""#Some tests...
event_num = 5
time_event = stb['time'][np.logical_and(stb['time'] > icme_start_time_num[n_istbind][event_num], stb['time'] < mo_start_time_num[n_istbind][event_num]+ feature_hours / 24.0)]
prop_event = stb['bt'][np.logical_and(stb['time'] > icme_start_time_num[n_istbind][event_num], stb['time'] < mo_start_time_num[n_istbind][event_num]+ feature_hours / 24.0)]
time_label = stb['time'][np.logical_and(stb['time'] > mo_start_time_num[n_istbind][event_num]+ feature_hours / 24.0, stb['time'] < mo_end_time_num[n_istbind][event_num])]
prop_label = stb['bt'][np.logical_and(stb['time'] > mo_start_time_num[n_istbind][event_num]+ feature_hours / 24.0, stb['time'] < mo_end_time_num[n_istbind][event_num])]
plt.plot(time_event,prop_event)
plt.plot(time_label,prop_label)
plt.scatter(icme_start_time_num[n_istbind][event_num],0.6, color='y')
plt.axvline(icme_start_time_num[n_istbind][event_num], color='y')
plt.scatter(mo_start_time_num[n_istbind][event_num],0.5, color='g')
plt.scatter(mo_start_time_num[n_istbind][event_num] + feature_hours / 24.0,0.4, color='b')
plt.scatter(mo_end_time_num[n_istbind][event_num],0.3, color='r')

print(np.nanmean(prop_event))
print(np.nanmax(prop_event))
print(np.nanstd(prop_event))
print(np.nanmin(prop_event))
print(np.nanstd(prop_event)/np.nanmean(prop_event))
print(np.nanmin(prop_event)/np.nanmax(prop_event))
#print(np.nanmean(prop_label))stb
"""
# Out:
# "#Some tests...\nevent_num = 5\ntime_event = stb['time'][np.logical_and(stb['time'] > icme_start_time_num[n_istbind][event_num], stb['time'] < mo_start_time_num[n_istbind][event_num]+ feature_hours / 24.0)]\nprop_event = stb['bt'][np.logical_and(stb['time'] > icme_start_time_num[n_istbind][event_num], stb['time'] < mo_start_time_num[n_istbind][event_num]+ feature_hours / 24.0)]\ntime_label = stb['time'][np.logical_and(stb['time'] > mo_start_time_num[n_istbind][event_num]+ feature_hours / 24.0, stb['time'] < mo_end_time_num[n_istbind][event_num])]\nprop_label = stb['bt'][np.logical_and(stb['time'] > mo_start_time_num[n_istbind][event_num]+ feature_hours / 24.0, stb['time'] < mo_end_time_num[n_istbind][event_num])]\nplt.plot(time_event,prop_event)\nplt.plot(time_label,prop_label)\nplt.scatter(icme_start_time_num[n_istbind][event_num],0.6, color='y')\nplt.axvline(icme_start_time_num[n_istbind][event_num], color='y')\nplt.scatter(mo_start_time_num[n_istbind][event_num],0.5, color='g')\nplt.scatter(mo_start_time_num[n_istbind][event_num] + feature_hours / 24.0,0.4, color='b')\nplt.scatter(mo_end_time_num[n_istbind][event_num],0.3, color='r')\n\nprint(np.nanmean(prop_event))\nprint(np.nanmax(prop_event))\nprint(np.nanstd(prop_event))\nprint(np.nanmin(prop_event))\nprint(np.nanstd(prop_event)/np.nanmean(prop_event))\nprint(np.nanmin(prop_event)/np.nanmax(prop_event))\n#print(np.nanmean(prop_label))stb\n"

# %% [markdown]
# ## 2. Machine Learning

# %% [markdown]
# ## Feedforward NN

# %%
import tensorflow as tf

class NN(tf.keras.Model):

  def __init__(self):
    super(NN, self).__init__()
    self.dense1 = tf.keras.layers.Dense(64, activation=tf.keras.activations.linear)
    self.dense2 = tf.keras.layers.Dense(128, activation=tf.keras.activations.linear)
    self.dense3 = tf.keras.layers.Dense(256, activation=tf.keras.activations.linear)
    self.dense4 = tf.keras.layers.Dense(1, activation=tf.keras.activations.linear)
   

  def call(self, inputs):
    x1 = self.dense1(inputs)
    x2 = self.dense2(x1)
    x3 = self.dense3(x2)
    x4 = self.dense4(x3)
    return x4

model = NN()
model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanSquaredError(), tf.keras.metrics.MeanAbsoluteError()])
#tf.optimizers.RMSprop(0.001)

# %%
model.fit(X_train, y_train, batch_size=16, epochs=10000)
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 7501/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 62.1454 - root_mean_squared_error: 7.8832 - mean_squared_error: 62.1454 - mean_absolute_error: 5.3990
# Epoch 7502/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 69.5977 - root_mean_squared_error: 8.3425 - mean_squared_error: 69.5977 - mean_absolute_error: 5.2566
# Epoch 7503/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 60.1079 - root_mean_squared_error: 7.7529 - mean_squared_error: 60.1079 - mean_absolute_error: 5.0934
# Epoch 7504/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 49.2986 - root_mean_squared_error: 7.0213 - mean_squared_error: 49.2986 - mean_absolute_error: 4.9861
# Epoch 7505/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 46.4022 - root_mean_squared_error: 6.8119 - mean_squared_error: 46.4022 - mean_absolute_error: 4.9404
# Epoch 7506/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 47.1711 - root_mean_squared_error: 6.8681 - mean_squared_error: 47.1711 - mean_absolute_error: 4.5654
# Epoch 7507/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 81.1472 - root_mean_squared_error: 9.0082 - mean_squared_error: 81.1472 - mean_absolute_error: 5.5726
# Epoch 7508/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 55.5743 - root_mean_squared_error: 7.4548 - mean_squared_error: 55.5743 - mean_absolute_error: 4.9635
# Epoch 7509/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 98.0717 - root_mean_squared_error: 9.9031 - mean_squared_error: 98.0717 - mean_absolute_error: 6.5060
# Epoch 7510/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 72.9932 - root_mean_squared_error: 8.5436 - mean_squared_error: 72.9932 - mean_absolute_error: 5.3323
# Epoch 7511/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 50.1788 - root_mean_squared_error: 7.0837 - mean_squared_error: 50.1788 - mean_absolute_error: 4.8087
# Epoch 7512/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 70.0156 - root_mean_squared_error: 8.3675 - mean_squared_error: 70.0156 - mean_absolute_error: 5.2094
# Epoch 7513/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 108.7590 - root_mean_squared_error: 10.4288 - mean_squared_error: 108.7590 - mean_absolute_error: 6.8614
# Epoch 7514/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 110.2847 - root_mean_squared_error: 10.5017 - mean_squared_error: 110.2847 - mean_absolute_error: 7.0136
# Epoch 7515/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 110.6128 - root_mean_squared_error: 10.5173 - mean_squared_error: 110.6128 - mean_absolute_error: 6.7970
# Epoch 7516/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 142.7834 - root_mean_squared_error: 11.9492 - mean_squared_error: 142.7834 - mean_absolute_error: 7.3346
# Epoch 7517/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 133.0213 - root_mean_squared_error: 11.5335 - mean_squared_error: 133.0213 - mean_absolute_error: 6.9787
# Epoch 7518/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 74.7003 - root_mean_squared_error: 8.6429 - mean_squared_error: 74.7003 - mean_absolute_error: 6.2475
# Epoch 7519/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 149.0156 - root_mean_squared_error: 12.2072 - mean_squared_error: 149.0156 - mean_absolute_error: 7.7507
# Epoch 7520/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 87.9687 - root_mean_squared_error: 9.3792 - mean_squared_error: 87.9687 - mean_absolute_error: 6.6361
# Epoch 7521/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 198.9382 - root_mean_squared_error: 14.1045 - mean_squared_error: 198.9382 - mean_absolute_error: 7.9215
# Epoch 7522/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 101.4049 - root_mean_squared_error: 10.0700 - mean_squared_error: 101.4049 - mean_absolute_error: 6.2912
# Epoch 7523/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 71.3345 - root_mean_squared_error: 8.4460 - mean_squared_error: 71.3345 - mean_absolute_error: 5.6053
# Epoch 7524/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 52.2205 - root_mean_squared_error: 7.2264 - mean_squared_error: 52.2205 - mean_absolute_error: 4.8238
# Epoch 7525/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 39.8627 - root_mean_squared_error: 6.3137 - mean_squared_error: 39.8627 - mean_absolute_error: 4.5303
# Epoch 7526/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 56.4311 - root_mean_squared_error: 7.5121 - mean_squared_error: 56.4311 - mean_absolute_error: 4.9664
# Epoch 7527/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 45.1619 - root_mean_squared_error: 6.7203 - mean_squared_error: 45.1619 - mean_absolute_error: 4.5768
# Epoch 7528/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 41.4554 - root_mean_squared_error: 6.4386 - mean_squared_error: 41.4554 - mean_absolute_error: 4.5153
# Epoch 7529/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 36.2439 - root_mean_squared_error: 6.0203 - mean_squared_error: 36.2439 - mean_absolute_error: 4.3248
# Epoch 7530/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 37.4652 - root_mean_squared_error: 6.1209 - mean_squared_error: 37.4652 - mean_absolute_error: 4.2968
# Epoch 7531/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 66.1741 - root_mean_squared_error: 8.1347 - mean_squared_error: 66.1741 - mean_absolute_error: 5.2156
# Epoch 7532/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 147.2409 - root_mean_squared_error: 12.1343 - mean_squared_error: 147.2409 - mean_absolute_error: 8.0849
# Epoch 7533/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 138.0435 - root_mean_squared_error: 11.7492 - mean_squared_error: 138.0435 - mean_absolute_error: 7.5412
# Epoch 7534/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 198.7671 - root_mean_squared_error: 14.0985 - mean_squared_error: 198.7671 - mean_absolute_error: 8.2576
# Epoch 7535/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 120.2209 - root_mean_squared_error: 10.9645 - mean_squared_error: 120.2209 - mean_absolute_error: 7.1708
# Epoch 7536/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 150.7787 - root_mean_squared_error: 12.2792 - mean_squared_error: 150.7787 - mean_absolute_error: 7.5743
# Epoch 7537/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 514.1448 - root_mean_squared_error: 22.6748 - mean_squared_error: 514.1448 - mean_absolute_error: 13.2310
# Epoch 7538/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 1077.8264 - root_mean_squared_error: 32.8303 - mean_squared_error: 1077.8264 - mean_absolute_error: 20.7519
# Epoch 7539/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 1583.5236 - root_mean_squared_error: 39.7935 - mean_squared_error: 1583.5236 - mean_absolute_error: 23.0890
# Epoch 7540/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 952.8628 - root_mean_squared_error: 30.8685 - mean_squared_error: 952.8628 - mean_absolute_error: 17.4026
# Epoch 7541/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 267.7520 - root_mean_squared_error: 16.3631 - mean_squared_error: 267.7520 - mean_absolute_error: 10.4890
# Epoch 7542/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 181.0279 - root_mean_squared_error: 13.4547 - mean_squared_error: 181.0279 - mean_absolute_error: 8.1836
# Epoch 7543/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 67.8409 - root_mean_squared_error: 8.2366 - mean_squared_error: 67.8409 - mean_absolute_error: 5.4839
# Epoch 7544/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 44.1228 - root_mean_squared_error: 6.6425 - mean_squared_error: 44.1228 - mean_absolute_error: 4.6645
# Epoch 7545/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 45.3293 - root_mean_squared_error: 6.7327 - mean_squared_error: 45.3293 - mean_absolute_error: 4.7521
# Epoch 7546/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 36.5751 - root_mean_squared_error: 6.0477 - mean_squared_error: 36.5751 - mean_absolute_error: 4.2678
# Epoch 7547/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 37.4262 - root_mean_squared_error: 6.1177 - mean_squared_error: 37.4262 - mean_absolute_error: 4.2879
# Epoch 7548/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 35.0024 - root_mean_squared_error: 5.9163 - mean_squared_error: 35.0024 - mean_absolute_error: 4.2094
# Epoch 7549/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 37.9314 - root_mean_squared_error: 6.1589 - mean_squared_error: 37.9314 - mean_absolute_error: 4.3749
# Epoch 7550/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 38.0661 - root_mean_squared_error: 6.1698 - mean_squared_error: 38.0661 - mean_absolute_error: 4.2890
# Epoch 7551/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 39.6269 - root_mean_squared_error: 6.2950 - mean_squared_error: 39.6269 - mean_absolute_error: 4.4327
# Epoch 7552/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 39.8560 - root_mean_squared_error: 6.3132 - mean_squared_error: 39.8560 - mean_absolute_error: 4.4394
# Epoch 7553/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 53.0884 - root_mean_squared_error: 7.2862 - mean_squared_error: 53.0884 - mean_absolute_error: 4.7719
# Epoch 7554/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 40.3987 - root_mean_squared_error: 6.3560 - mean_squared_error: 40.3987 - mean_absolute_error: 4.6165
# Epoch 7555/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 69.1232 - root_mean_squared_error: 8.3140 - mean_squared_error: 69.1232 - mean_absolute_error: 5.1838
# Epoch 7556/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 38.8819 - root_mean_squared_error: 6.2355 - mean_squared_error: 38.8819 - mean_absolute_error: 4.3919
# Epoch 7557/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 52.8803 - root_mean_squared_error: 7.2719 - mean_squared_error: 52.8803 - mean_absolute_error: 4.9618
# Epoch 7558/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 82.8266 - root_mean_squared_error: 9.1009 - mean_squared_error: 82.8266 - mean_absolute_error: 5.1361
# Epoch 7559/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 41.7300 - root_mean_squared_error: 6.4599 - mean_squared_error: 41.7300 - mean_absolute_error: 4.3254
# Epoch 7560/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 42.3192 - root_mean_squared_error: 6.5053 - mean_squared_error: 42.3192 - mean_absolute_error: 4.5979
# Epoch 7561/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 51.8572 - root_mean_squared_error: 7.2012 - mean_squared_error: 51.8572 - mean_absolute_error: 4.6560
# Epoch 7562/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 72.0947 - root_mean_squared_error: 8.4909 - mean_squared_error: 72.0947 - mean_absolute_error: 5.3937
# Epoch 7563/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 92.8504 - root_mean_squared_error: 9.6359 - mean_squared_error: 92.8504 - mean_absolute_error: 6.5935
# Epoch 7564/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 105.3107 - root_mean_squared_error: 10.2621 - mean_squared_error: 105.3107 - mean_absolute_error: 6.4346
# Epoch 7565/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 111.0465 - root_mean_squared_error: 10.5379 - mean_squared_error: 111.0465 - mean_absolute_error: 6.4165
# Epoch 7566/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 81.8474 - root_mean_squared_error: 9.0470 - mean_squared_error: 81.8474 - mean_absolute_error: 5.6180
# Epoch 7567/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 47.7166 - root_mean_squared_error: 6.9077 - mean_squared_error: 47.7166 - mean_absolute_error: 4.7152
# Epoch 7568/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 48.9318 - root_mean_squared_error: 6.9951 - mean_squared_error: 48.9318 - mean_absolute_error: 4.9187
# Epoch 7569/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 62.6280 - root_mean_squared_error: 7.9138 - mean_squared_error: 62.6280 - mean_absolute_error: 5.2934
# Epoch 7570/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 44.6904 - root_mean_squared_error: 6.6851 - mean_squared_error: 44.6904 - mean_absolute_error: 4.7978
# Epoch 7571/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 57.1703 - root_mean_squared_error: 7.5611 - mean_squared_error: 57.1703 - mean_absolute_error: 4.7225
# Epoch 7572/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 57.6788 - root_mean_squared_error: 7.5947 - mean_squared_error: 57.6788 - mean_absolute_error: 5.1618
# Epoch 7573/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 69.7931 - root_mean_squared_error: 8.3542 - mean_squared_error: 69.7931 - mean_absolute_error: 5.1392
# Epoch 7574/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 73.5780 - root_mean_squared_error: 8.5778 - mean_squared_error: 73.5780 - mean_absolute_error: 5.8881
# Epoch 7575/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 93.1097 - root_mean_squared_error: 9.6493 - mean_squared_error: 93.1097 - mean_absolute_error: 6.4328
# Epoch 7576/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 59.5028 - root_mean_squared_error: 7.7138 - mean_squared_error: 59.5028 - mean_absolute_error: 5.3589
# Epoch 7577/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 38.3355 - root_mean_squared_error: 6.1916 - mean_squared_error: 38.3355 - mean_absolute_error: 4.4023
# Epoch 7578/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 34.3079 - root_mean_squared_error: 5.8573 - mean_squared_error: 34.3079 - mean_absolute_error: 4.1971
# Epoch 7579/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 40.6008 - root_mean_squared_error: 6.3719 - mean_squared_error: 40.6008 - mean_absolute_error: 4.4786
# Epoch 7580/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 87.7231 - root_mean_squared_error: 9.3661 - mean_squared_error: 87.7231 - mean_absolute_error: 5.6968
# Epoch 7581/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 88.2920 - root_mean_squared_error: 9.3964 - mean_squared_error: 88.2920 - mean_absolute_error: 5.9160
# Epoch 7582/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 113.2797 - root_mean_squared_error: 10.6433 - mean_squared_error: 113.2797 - mean_absolute_error: 6.5044
# Epoch 7583/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 91.2435 - root_mean_squared_error: 9.5521 - mean_squared_error: 91.2435 - mean_absolute_error: 6.5916
# Epoch 7584/10000
# 16/16 [==============================] - 0s 2ms/step - loss: 42.6028 - root_mean_squared_error: 6.5271 - mean_squared_error: 42.6028 - mean_absolute_error: 4.7877
# Epoch 7585/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 56.5314 - root_mean_squared_error: 7.5187 - mean_squared_error: 56.5314 - mean_absolute_error: 4.8400
# Epoch 7586/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 130.0577 - root_mean_squared_error: 11.4043 - mean_squared_error: 130.0577 - mean_absolute_error: 6.9849
# Epoch 7587/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 81.4788 - root_mean_squared_error: 9.0266 - mean_squared_error: 81.4788 - mean_absolute_error: 5.9670
# Epoch 7588/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 61.6600 - root_mean_squared_error: 7.8524 - mean_squared_error: 61.6600 - mean_absolute_error: 5.4582
# Epoch 7589/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 61.7026 - root_mean_squared_error: 7.8551 - mean_squared_error: 61.7026 - mean_absolute_error: 5.2841
# Epoch 7590/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 64.6166 - root_mean_squared_error: 8.0384 - mean_squared_error: 64.6166 - mean_absolute_error: 5.1570
# Epoch 7591/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 52.9865 - root_mean_squared_error: 7.2792 - mean_squared_error: 52.9865 - mean_absolute_error: 5.1038
# Epoch 7592/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 53.3118 - root_mean_squared_error: 7.3015 - mean_squared_error: 53.3118 - mean_absolute_error: 5.1765
# Epoch 7593/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 74.3599 - root_mean_squared_error: 8.6232 - mean_squared_error: 74.3599 - mean_absolute_error: 6.1064
# Epoch 7594/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 54.6449 - root_mean_squared_error: 7.3922 - mean_squared_error: 54.6449 - mean_absolute_error: 5.0439
# Epoch 7595/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 36.8649 - root_mean_squared_error: 6.0716 - mean_squared_error: 36.8649 - mean_absolute_error: 4.2959
# Epoch 7596/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 38.5055 - root_mean_squared_error: 6.2053 - mean_squared_error: 38.5055 - mean_absolute_error: 4.3180
# Epoch 7597/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 32.6925 - root_mean_squared_error: 5.7177 - mean_squared_error: 32.6925 - mean_absolute_error: 4.2957
# Epoch 7598/10000
# 16/16 [==============================] - 0s 6ms/step - loss: 70.5618 - root_mean_squared_error: 8.4001 - mean_squared_error: 70.5618 - mean_absolute_error: 5.2712
# Epoch 7599/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 157.4259 - root_mean_squared_error: 12.5469 - mean_squared_error: 157.4259 - mean_absolute_error: 6.8982
# Epoch 7600/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 50.7046 - root_mean_squared_error: 7.1207 - mean_squared_error: 50.7046 - mean_absolute_error: 4.9287
# Epoch 7601/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 47.8377 - root_mean_squared_error: 6.9165 - mean_squared_error: 47.8377 - mean_absolute_error: 4.7301
# Epoch 7602/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 45.3605 - root_mean_squared_error: 6.7350 - mean_squared_error: 45.3605 - mean_absolute_error: 4.9197
# Epoch 7603/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 55.0382 - root_mean_squared_error: 7.4188 - mean_squared_error: 55.0382 - mean_absolute_error: 4.9415
# Epoch 7604/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 57.3375 - root_mean_squared_error: 7.5722 - mean_squared_error: 57.3375 - mean_absolute_error: 5.1486
# Epoch 7605/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 177.8825 - root_mean_squared_error: 13.3373 - mean_squared_error: 177.8825 - mean_absolute_error: 7.8454
# Epoch 7606/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 107.7573 - root_mean_squared_error: 10.3806 - mean_squared_error: 107.7573 - mean_absolute_error: 6.5806
# Epoch 7607/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 71.0174 - root_mean_squared_error: 8.4272 - mean_squared_error: 71.0174 - mean_absolute_error: 5.7465
# Epoch 7608/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 65.2012 - root_mean_squared_error: 8.0747 - mean_squared_error: 65.2012 - mean_absolute_error: 5.4419
# Epoch 7609/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 42.0584 - root_mean_squared_error: 6.4852 - mean_squared_error: 42.0584 - mean_absolute_error: 4.3571
# Epoch 7610/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 37.8207 - root_mean_squared_error: 6.1499 - mean_squared_error: 37.8207 - mean_absolute_error: 4.4707
# Epoch 7611/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 33.7299 - root_mean_squared_error: 5.8077 - mean_squared_error: 33.7299 - mean_absolute_error: 4.0866
# Epoch 7612/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 34.1943 - root_mean_squared_error: 5.8476 - mean_squared_error: 34.1943 - mean_absolute_error: 4.1495
# Epoch 7613/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 35.2046 - root_mean_squared_error: 5.9333 - mean_squared_error: 35.2046 - mean_absolute_error: 4.2833
# Epoch 7614/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 98.6938 - root_mean_squared_error: 9.9345 - mean_squared_error: 98.6938 - mean_absolute_error: 6.0436
# Epoch 7615/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 77.0878 - root_mean_squared_error: 8.7800 - mean_squared_error: 77.0878 - mean_absolute_error: 5.6232
# Epoch 7616/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 76.9805 - root_mean_squared_error: 8.7739 - mean_squared_error: 76.9805 - mean_absolute_error: 5.5745
# Epoch 7617/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 210.9380 - root_mean_squared_error: 14.5237 - mean_squared_error: 210.9380 - mean_absolute_error: 9.4658
# Epoch 7618/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 100.5896 - root_mean_squared_error: 10.0294 - mean_squared_error: 100.5896 - mean_absolute_error: 6.7493
# Epoch 7619/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 65.3835 - root_mean_squared_error: 8.0860 - mean_squared_error: 65.3835 - mean_absolute_error: 5.7060
# Epoch 7620/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 40.4289 - root_mean_squared_error: 6.3584 - mean_squared_error: 40.4289 - mean_absolute_error: 4.6349
# Epoch 7621/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 35.6598 - root_mean_squared_error: 5.9716 - mean_squared_error: 35.6598 - mean_absolute_error: 4.3505
# Epoch 7622/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 40.9933 - root_mean_squared_error: 6.4026 - mean_squared_error: 40.9933 - mean_absolute_error: 4.4624
# Epoch 7623/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 32.7781 - root_mean_squared_error: 5.7252 - mean_squared_error: 32.7781 - mean_absolute_error: 4.0098
# Epoch 7624/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 35.1143 - root_mean_squared_error: 5.9257 - mean_squared_error: 35.1143 - mean_absolute_error: 4.1164
# Epoch 7625/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 34.8137 - root_mean_squared_error: 5.9003 - mean_squared_error: 34.8137 - mean_absolute_error: 4.2398
# Epoch 7626/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 35.1428 - root_mean_squared_error: 5.9281 - mean_squared_error: 35.1428 - mean_absolute_error: 4.2716
# Epoch 7627/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 79.0979 - root_mean_squared_error: 8.8937 - mean_squared_error: 79.0979 - mean_absolute_error: 5.7244
# Epoch 7628/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 104.8659 - root_mean_squared_error: 10.2404 - mean_squared_error: 104.8659 - mean_absolute_error: 6.8260
# Epoch 7629/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 67.3016 - root_mean_squared_error: 8.2038 - mean_squared_error: 67.3016 - mean_absolute_error: 5.2982
# Epoch 7630/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 55.8534 - root_mean_squared_error: 7.4735 - mean_squared_error: 55.8534 - mean_absolute_error: 4.9715
# Epoch 7631/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 48.3358 - root_mean_squared_error: 6.9524 - mean_squared_error: 48.3358 - mean_absolute_error: 4.7904
# Epoch 7632/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 43.9165 - root_mean_squared_error: 6.6270 - mean_squared_error: 43.9165 - mean_absolute_error: 4.6473
# Epoch 7633/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 36.1244 - root_mean_squared_error: 6.0104 - mean_squared_error: 36.1244 - mean_absolute_error: 4.2801
# Epoch 7634/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 41.9414 - root_mean_squared_error: 6.4762 - mean_squared_error: 41.9414 - mean_absolute_error: 4.3088
# Epoch 7635/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 54.3254 - root_mean_squared_error: 7.3706 - mean_squared_error: 54.3254 - mean_absolute_error: 4.7994
# Epoch 7636/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 44.4564 - root_mean_squared_error: 6.6676 - mean_squared_error: 44.4564 - mean_absolute_error: 4.6222
# Epoch 7637/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 53.7344 - root_mean_squared_error: 7.3304 - mean_squared_error: 53.7344 - mean_absolute_error: 5.0520
# Epoch 7638/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 41.3115 - root_mean_squared_error: 6.4274 - mean_squared_error: 41.3115 - mean_absolute_error: 4.5104
# Epoch 7639/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 34.6594 - root_mean_squared_error: 5.8872 - mean_squared_error: 34.6594 - mean_absolute_error: 4.1932
# Epoch 7640/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 33.1427 - root_mean_squared_error: 5.7570 - mean_squared_error: 33.1427 - mean_absolute_error: 4.0655
# Epoch 7641/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 33.9860 - root_mean_squared_error: 5.8298 - mean_squared_error: 33.9860 - mean_absolute_error: 4.1834
# Epoch 7642/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 33.5254 - root_mean_squared_error: 5.7901 - mean_squared_error: 33.5254 - mean_absolute_error: 4.1300
# Epoch 7643/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 36.8531 - root_mean_squared_error: 6.0707 - mean_squared_error: 36.8531 - mean_absolute_error: 4.1990
# Epoch 7644/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 62.6339 - root_mean_squared_error: 7.9142 - mean_squared_error: 62.6339 - mean_absolute_error: 5.2330
# Epoch 7645/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 51.3656 - root_mean_squared_error: 7.1670 - mean_squared_error: 51.3656 - mean_absolute_error: 5.1450
# Epoch 7646/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 51.5627 - root_mean_squared_error: 7.1807 - mean_squared_error: 51.5627 - mean_absolute_error: 4.9167
# Epoch 7647/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 182.3997 - root_mean_squared_error: 13.5055 - mean_squared_error: 182.3997 - mean_absolute_error: 8.6111
# Epoch 7648/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 66.3332 - root_mean_squared_error: 8.1445 - mean_squared_error: 66.3332 - mean_absolute_error: 5.5675
# Epoch 7649/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 45.1749 - root_mean_squared_error: 6.7212 - mean_squared_error: 45.1749 - mean_absolute_error: 4.9969
# Epoch 7650/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 58.8472 - root_mean_squared_error: 7.6712 - mean_squared_error: 58.8472 - mean_absolute_error: 5.3205
# Epoch 7651/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 243.7996 - root_mean_squared_error: 15.6141 - mean_squared_error: 243.7996 - mean_absolute_error: 9.4168
# Epoch 7652/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 721.3517 - root_mean_squared_error: 26.8580 - mean_squared_error: 721.3517 - mean_absolute_error: 14.5975
# Epoch 7653/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 286.2379 - root_mean_squared_error: 16.9186 - mean_squared_error: 286.2379 - mean_absolute_error: 10.1395
# Epoch 7654/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 116.7001 - root_mean_squared_error: 10.8028 - mean_squared_error: 116.7001 - mean_absolute_error: 7.0209
# Epoch 7655/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 63.3270 - root_mean_squared_error: 7.9578 - mean_squared_error: 63.3270 - mean_absolute_error: 5.6553
# Epoch 7656/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 69.9276 - root_mean_squared_error: 8.3623 - mean_squared_error: 69.9276 - mean_absolute_error: 5.7467
# Epoch 7657/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 62.9903 - root_mean_squared_error: 7.9366 - mean_squared_error: 62.9903 - mean_absolute_error: 5.4791
# Epoch 7658/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 58.4714 - root_mean_squared_error: 7.6467 - mean_squared_error: 58.4714 - mean_absolute_error: 5.3979
# Epoch 7659/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 46.2868 - root_mean_squared_error: 6.8034 - mean_squared_error: 46.2868 - mean_absolute_error: 4.5483
# Epoch 7660/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 51.7354 - root_mean_squared_error: 7.1927 - mean_squared_error: 51.7354 - mean_absolute_error: 5.0274
# Epoch 7661/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 43.9454 - root_mean_squared_error: 6.6291 - mean_squared_error: 43.9454 - mean_absolute_error: 4.6988
# Epoch 7662/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 44.3384 - root_mean_squared_error: 6.6587 - mean_squared_error: 44.3384 - mean_absolute_error: 4.5758
# Epoch 7663/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 40.0911 - root_mean_squared_error: 6.3318 - mean_squared_error: 40.0911 - mean_absolute_error: 4.6371
# Epoch 7664/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 45.7680 - root_mean_squared_error: 6.7652 - mean_squared_error: 45.7680 - mean_absolute_error: 4.5856
# Epoch 7665/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 37.4812 - root_mean_squared_error: 6.1222 - mean_squared_error: 37.4812 - mean_absolute_error: 4.3516
# Epoch 7666/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 33.3842 - root_mean_squared_error: 5.7779 - mean_squared_error: 33.3842 - mean_absolute_error: 4.1317
# Epoch 7667/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 38.0985 - root_mean_squared_error: 6.1724 - mean_squared_error: 38.0985 - mean_absolute_error: 4.2936
# Epoch 7668/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 55.7457 - root_mean_squared_error: 7.4663 - mean_squared_error: 55.7457 - mean_absolute_error: 5.0454
# Epoch 7669/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 55.5761 - root_mean_squared_error: 7.4549 - mean_squared_error: 55.5761 - mean_absolute_error: 5.0567
# Epoch 7670/10000
# 16/16 [==============================] - 0s 6ms/step - loss: 44.5842 - root_mean_squared_error: 6.6771 - mean_squared_error: 44.5842 - mean_absolute_error: 4.8246
# Epoch 7671/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 33.8874 - root_mean_squared_error: 5.8213 - mean_squared_error: 33.8874 - mean_absolute_error: 4.1574
# Epoch 7672/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 54.0098 - root_mean_squared_error: 7.3491 - mean_squared_error: 54.0098 - mean_absolute_error: 5.0392
# Epoch 7673/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 37.2634 - root_mean_squared_error: 6.1044 - mean_squared_error: 37.2634 - mean_absolute_error: 4.4088
# Epoch 7674/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 33.2549 - root_mean_squared_error: 5.7667 - mean_squared_error: 33.2549 - mean_absolute_error: 4.2501
# Epoch 7675/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 35.4785 - root_mean_squared_error: 5.9564 - mean_squared_error: 35.4785 - mean_absolute_error: 4.2538
# Epoch 7676/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 35.9875 - root_mean_squared_error: 5.9990 - mean_squared_error: 35.9875 - mean_absolute_error: 4.3607
# Epoch 7677/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 37.7902 - root_mean_squared_error: 6.1474 - mean_squared_error: 37.7902 - mean_absolute_error: 4.2457
# Epoch 7678/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 33.8350 - root_mean_squared_error: 5.8168 - mean_squared_error: 33.8350 - mean_absolute_error: 4.0967
# Epoch 7679/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 40.4795 - root_mean_squared_error: 6.3624 - mean_squared_error: 40.4795 - mean_absolute_error: 4.5636
# Epoch 7680/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 36.0286 - root_mean_squared_error: 6.0024 - mean_squared_error: 36.0286 - mean_absolute_error: 4.2867
# Epoch 7681/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 36.9708 - root_mean_squared_error: 6.0804 - mean_squared_error: 36.9708 - mean_absolute_error: 4.2500
# Epoch 7682/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 32.2171 - root_mean_squared_error: 5.6760 - mean_squared_error: 32.2171 - mean_absolute_error: 4.0039
# Epoch 7683/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 31.2519 - root_mean_squared_error: 5.5903 - mean_squared_error: 31.2519 - mean_absolute_error: 3.9808
# Epoch 7684/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 31.7706 - root_mean_squared_error: 5.6365 - mean_squared_error: 31.7706 - mean_absolute_error: 3.9817
# Epoch 7685/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 48.3975 - root_mean_squared_error: 6.9568 - mean_squared_error: 48.3975 - mean_absolute_error: 4.8806
# Epoch 7686/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 54.1806 - root_mean_squared_error: 7.3607 - mean_squared_error: 54.1806 - mean_absolute_error: 5.1719
# Epoch 7687/10000
# 16/16 [==============================] - 0s 6ms/step - loss: 56.9585 - root_mean_squared_error: 7.5471 - mean_squared_error: 56.9585 - mean_absolute_error: 5.3782
# Epoch 7688/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 63.0908 - root_mean_squared_error: 7.9430 - mean_squared_error: 63.0908 - mean_absolute_error: 5.6026
# Epoch 7689/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 50.5443 - root_mean_squared_error: 7.1095 - mean_squared_error: 50.5443 - mean_absolute_error: 5.1835
# Epoch 7690/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 35.9636 - root_mean_squared_error: 5.9970 - mean_squared_error: 35.9636 - mean_absolute_error: 4.2856
# Epoch 7691/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 34.5950 - root_mean_squared_error: 5.8818 - mean_squared_error: 34.5950 - mean_absolute_error: 4.2231
# Epoch 7692/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 37.8133 - root_mean_squared_error: 6.1493 - mean_squared_error: 37.8133 - mean_absolute_error: 4.3103
# Epoch 7693/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 37.9154 - root_mean_squared_error: 6.1575 - mean_squared_error: 37.9154 - mean_absolute_error: 4.2498
# Epoch 7694/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 38.4430 - root_mean_squared_error: 6.2002 - mean_squared_error: 38.4430 - mean_absolute_error: 4.4497
# Epoch 7695/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 37.8089 - root_mean_squared_error: 6.1489 - mean_squared_error: 37.8089 - mean_absolute_error: 4.3827
# Epoch 7696/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 33.6754 - root_mean_squared_error: 5.8031 - mean_squared_error: 33.6754 - mean_absolute_error: 4.1453
# Epoch 7697/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 47.7366 - root_mean_squared_error: 6.9092 - mean_squared_error: 47.7366 - mean_absolute_error: 4.5496
# Epoch 7698/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 32.4200 - root_mean_squared_error: 5.6939 - mean_squared_error: 32.4200 - mean_absolute_error: 3.9096
# Epoch 7699/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 32.4421 - root_mean_squared_error: 5.6958 - mean_squared_error: 32.4421 - mean_absolute_error: 4.0713
# Epoch 7700/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 35.9717 - root_mean_squared_error: 5.9976 - mean_squared_error: 35.9717 - mean_absolute_error: 4.1696
# Epoch 7701/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 40.1153 - root_mean_squared_error: 6.3337 - mean_squared_error: 40.1153 - mean_absolute_error: 4.4120
# Epoch 7702/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 40.9144 - root_mean_squared_error: 6.3964 - mean_squared_error: 40.9144 - mean_absolute_error: 4.3328
# Epoch 7703/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 32.5487 - root_mean_squared_error: 5.7051 - mean_squared_error: 32.5487 - mean_absolute_error: 4.2850
# Epoch 7704/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 41.7234 - root_mean_squared_error: 6.4594 - mean_squared_error: 41.7234 - mean_absolute_error: 4.3469
# Epoch 7705/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 51.4561 - root_mean_squared_error: 7.1733 - mean_squared_error: 51.4561 - mean_absolute_error: 4.8824
# Epoch 7706/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 37.1863 - root_mean_squared_error: 6.0981 - mean_squared_error: 37.1863 - mean_absolute_error: 4.4121
# Epoch 7707/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 35.0806 - root_mean_squared_error: 5.9229 - mean_squared_error: 35.0806 - mean_absolute_error: 4.2748
# Epoch 7708/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 66.7008 - root_mean_squared_error: 8.1671 - mean_squared_error: 66.7008 - mean_absolute_error: 5.4240
# Epoch 7709/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 57.5131 - root_mean_squared_error: 7.5837 - mean_squared_error: 57.5131 - mean_absolute_error: 5.8044
# Epoch 7710/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 44.6020 - root_mean_squared_error: 6.6785 - mean_squared_error: 44.6020 - mean_absolute_error: 4.6017
# Epoch 7711/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 40.3698 - root_mean_squared_error: 6.3537 - mean_squared_error: 40.3698 - mean_absolute_error: 4.4631
# Epoch 7712/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 41.1088 - root_mean_squared_error: 6.4116 - mean_squared_error: 41.1088 - mean_absolute_error: 4.4328
# Epoch 7713/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 38.5174 - root_mean_squared_error: 6.2062 - mean_squared_error: 38.5174 - mean_absolute_error: 4.3354
# Epoch 7714/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 44.7422 - root_mean_squared_error: 6.6890 - mean_squared_error: 44.7422 - mean_absolute_error: 4.8330
# Epoch 7715/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 41.4872 - root_mean_squared_error: 6.4411 - mean_squared_error: 41.4872 - mean_absolute_error: 4.4402
# Epoch 7716/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 39.7867 - root_mean_squared_error: 6.3077 - mean_squared_error: 39.7867 - mean_absolute_error: 4.5381
# Epoch 7717/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 42.8250 - root_mean_squared_error: 6.5441 - mean_squared_error: 42.8250 - mean_absolute_error: 4.9793
# Epoch 7718/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 34.7551 - root_mean_squared_error: 5.8953 - mean_squared_error: 34.7551 - mean_absolute_error: 4.3357
# Epoch 7719/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 40.2882 - root_mean_squared_error: 6.3473 - mean_squared_error: 40.2882 - mean_absolute_error: 4.4693
# Epoch 7720/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 39.4799 - root_mean_squared_error: 6.2833 - mean_squared_error: 39.4799 - mean_absolute_error: 4.3634
# Epoch 7721/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 34.1269 - root_mean_squared_error: 5.8418 - mean_squared_error: 34.1269 - mean_absolute_error: 4.2597
# Epoch 7722/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 30.5657 - root_mean_squared_error: 5.5286 - mean_squared_error: 30.5657 - mean_absolute_error: 3.9556
# Epoch 7723/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 47.7720 - root_mean_squared_error: 6.9117 - mean_squared_error: 47.7720 - mean_absolute_error: 4.5539
# Epoch 7724/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 47.5484 - root_mean_squared_error: 6.8955 - mean_squared_error: 47.5484 - mean_absolute_error: 4.6715
# Epoch 7725/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 49.5203 - root_mean_squared_error: 7.0371 - mean_squared_error: 49.5203 - mean_absolute_error: 5.0500
# Epoch 7726/10000
# 16/16 [==============================] - 0s 6ms/step - loss: 85.1373 - root_mean_squared_error: 9.2270 - mean_squared_error: 85.1373 - mean_absolute_error: 6.2113
# Epoch 7727/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 43.8831 - root_mean_squared_error: 6.6244 - mean_squared_error: 43.8831 - mean_absolute_error: 4.6232
# Epoch 7728/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 33.9329 - root_mean_squared_error: 5.8252 - mean_squared_error: 33.9329 - mean_absolute_error: 4.1700
# Epoch 7729/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 39.2940 - root_mean_squared_error: 6.2685 - mean_squared_error: 39.2940 - mean_absolute_error: 4.3422
# Epoch 7730/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 31.4454 - root_mean_squared_error: 5.6076 - mean_squared_error: 31.4454 - mean_absolute_error: 4.0939
# Epoch 7731/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 59.3998 - root_mean_squared_error: 7.7071 - mean_squared_error: 59.3998 - mean_absolute_error: 5.4955
# Epoch 7732/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 47.8651 - root_mean_squared_error: 6.9185 - mean_squared_error: 47.8651 - mean_absolute_error: 4.8028
# Epoch 7733/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 49.6970 - root_mean_squared_error: 7.0496 - mean_squared_error: 49.6970 - mean_absolute_error: 4.8921
# Epoch 7734/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 37.3758 - root_mean_squared_error: 6.1136 - mean_squared_error: 37.3758 - mean_absolute_error: 4.5127
# Epoch 7735/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 69.0672 - root_mean_squared_error: 8.3107 - mean_squared_error: 69.0672 - mean_absolute_error: 5.5263
# Epoch 7736/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 40.8792 - root_mean_squared_error: 6.3937 - mean_squared_error: 40.8792 - mean_absolute_error: 4.4895
# Epoch 7737/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 41.4483 - root_mean_squared_error: 6.4380 - mean_squared_error: 41.4483 - mean_absolute_error: 4.4956
# Epoch 7738/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 46.1976 - root_mean_squared_error: 6.7969 - mean_squared_error: 46.1976 - mean_absolute_error: 4.6526
# Epoch 7739/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 34.0711 - root_mean_squared_error: 5.8370 - mean_squared_error: 34.0711 - mean_absolute_error: 4.0667
# Epoch 7740/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 40.5594 - root_mean_squared_error: 6.3686 - mean_squared_error: 40.5594 - mean_absolute_error: 4.4876
# Epoch 7741/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 36.0368 - root_mean_squared_error: 6.0031 - mean_squared_error: 36.0368 - mean_absolute_error: 4.3261
# Epoch 7742/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 39.0152 - root_mean_squared_error: 6.2462 - mean_squared_error: 39.0152 - mean_absolute_error: 4.4560
# Epoch 7743/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 47.1287 - root_mean_squared_error: 6.8650 - mean_squared_error: 47.1287 - mean_absolute_error: 4.6365
# Epoch 7744/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 44.5532 - root_mean_squared_error: 6.6748 - mean_squared_error: 44.5532 - mean_absolute_error: 4.8800
# Epoch 7745/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 39.1705 - root_mean_squared_error: 6.2586 - mean_squared_error: 39.1705 - mean_absolute_error: 4.4406
# Epoch 7746/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 34.9960 - root_mean_squared_error: 5.9157 - mean_squared_error: 34.9960 - mean_absolute_error: 4.2794
# Epoch 7747/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 87.6234 - root_mean_squared_error: 9.3607 - mean_squared_error: 87.6234 - mean_absolute_error: 5.4523
# Epoch 7748/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 58.1562 - root_mean_squared_error: 7.6260 - mean_squared_error: 58.1562 - mean_absolute_error: 5.3188
# Epoch 7749/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 71.7712 - root_mean_squared_error: 8.4718 - mean_squared_error: 71.7712 - mean_absolute_error: 5.7283
# Epoch 7750/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 43.8736 - root_mean_squared_error: 6.6237 - mean_squared_error: 43.8736 - mean_absolute_error: 4.8380
# Epoch 7751/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 38.9905 - root_mean_squared_error: 6.2442 - mean_squared_error: 38.9905 - mean_absolute_error: 4.4114
# Epoch 7752/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 32.5642 - root_mean_squared_error: 5.7065 - mean_squared_error: 32.5642 - mean_absolute_error: 4.2646
# Epoch 7753/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 54.3529 - root_mean_squared_error: 7.3724 - mean_squared_error: 54.3529 - mean_absolute_error: 4.8404
# Epoch 7754/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 39.1813 - root_mean_squared_error: 6.2595 - mean_squared_error: 39.1813 - mean_absolute_error: 4.3925
# Epoch 7755/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 35.0607 - root_mean_squared_error: 5.9212 - mean_squared_error: 35.0607 - mean_absolute_error: 4.2225
# Epoch 7756/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 34.6208 - root_mean_squared_error: 5.8839 - mean_squared_error: 34.6208 - mean_absolute_error: 4.1490
# Epoch 7757/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 32.5934 - root_mean_squared_error: 5.7091 - mean_squared_error: 32.5934 - mean_absolute_error: 4.0305
# Epoch 7758/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 29.6843 - root_mean_squared_error: 5.4483 - mean_squared_error: 29.6843 - mean_absolute_error: 3.9352
# Epoch 7759/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 39.5855 - root_mean_squared_error: 6.2917 - mean_squared_error: 39.5855 - mean_absolute_error: 4.2993
# Epoch 7760/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 35.6369 - root_mean_squared_error: 5.9697 - mean_squared_error: 35.6369 - mean_absolute_error: 4.4862
# Epoch 7761/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 32.6243 - root_mean_squared_error: 5.7118 - mean_squared_error: 32.6243 - mean_absolute_error: 4.2015
# Epoch 7762/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 31.4541 - root_mean_squared_error: 5.6084 - mean_squared_error: 31.4541 - mean_absolute_error: 4.1304
# Epoch 7763/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 32.0668 - root_mean_squared_error: 5.6628 - mean_squared_error: 32.0668 - mean_absolute_error: 4.1038
# Epoch 7764/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 34.4129 - root_mean_squared_error: 5.8662 - mean_squared_error: 34.4129 - mean_absolute_error: 4.1173
# Epoch 7765/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 41.7049 - root_mean_squared_error: 6.4579 - mean_squared_error: 41.7049 - mean_absolute_error: 4.6193
# Epoch 7766/10000
# ...
# Epoch 9913/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 30.7001 - root_mean_squared_error: 5.5408 - mean_squared_error: 30.7001 - mean_absolute_error: 4.0006
# Epoch 9914/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 30.5972 - root_mean_squared_error: 5.5315 - mean_squared_error: 30.5972 - mean_absolute_error: 3.8141
# Epoch 9915/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 48.5776 - root_mean_squared_error: 6.9698 - mean_squared_error: 48.5776 - mean_absolute_error: 4.5814
# Epoch 9916/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 31.1423 - root_mean_squared_error: 5.5805 - mean_squared_error: 31.1423 - mean_absolute_error: 4.0171
# Epoch 9917/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 34.5604 - root_mean_squared_error: 5.8788 - mean_squared_error: 34.5604 - mean_absolute_error: 3.9234
# Epoch 9918/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 30.7715 - root_mean_squared_error: 5.5472 - mean_squared_error: 30.7715 - mean_absolute_error: 3.9341
# Epoch 9919/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 27.9371 - root_mean_squared_error: 5.2856 - mean_squared_error: 27.9371 - mean_absolute_error: 3.7708
# Epoch 9920/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 53.2127 - root_mean_squared_error: 7.2947 - mean_squared_error: 53.2127 - mean_absolute_error: 4.8705
# Epoch 9921/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 38.8848 - root_mean_squared_error: 6.2358 - mean_squared_error: 38.8848 - mean_absolute_error: 4.4239
# Epoch 9922/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 27.2589 - root_mean_squared_error: 5.2210 - mean_squared_error: 27.2589 - mean_absolute_error: 3.7928
# Epoch 9923/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 29.9988 - root_mean_squared_error: 5.4771 - mean_squared_error: 29.9988 - mean_absolute_error: 4.0780
# Epoch 9924/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 33.7020 - root_mean_squared_error: 5.8053 - mean_squared_error: 33.7020 - mean_absolute_error: 3.9423
# Epoch 9925/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 44.9528 - root_mean_squared_error: 6.7047 - mean_squared_error: 44.9528 - mean_absolute_error: 4.7677
# Epoch 9926/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 36.3650 - root_mean_squared_error: 6.0303 - mean_squared_error: 36.3650 - mean_absolute_error: 4.4176
# Epoch 9927/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 31.7678 - root_mean_squared_error: 5.6363 - mean_squared_error: 31.7678 - mean_absolute_error: 4.0133
# Epoch 9928/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 29.6408 - root_mean_squared_error: 5.4443 - mean_squared_error: 29.6408 - mean_absolute_error: 3.8031
# Epoch 9929/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 32.6230 - root_mean_squared_error: 5.7117 - mean_squared_error: 32.6230 - mean_absolute_error: 4.0710
# Epoch 9930/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 30.5024 - root_mean_squared_error: 5.5229 - mean_squared_error: 30.5024 - mean_absolute_error: 3.7463
# Epoch 9931/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 33.9328 - root_mean_squared_error: 5.8252 - mean_squared_error: 33.9328 - mean_absolute_error: 4.1210
# Epoch 9932/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 31.7260 - root_mean_squared_error: 5.6326 - mean_squared_error: 31.7260 - mean_absolute_error: 3.9105
# Epoch 9933/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 31.3251 - root_mean_squared_error: 5.5969 - mean_squared_error: 31.3251 - mean_absolute_error: 3.8395
# Epoch 9934/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 29.4727 - root_mean_squared_error: 5.4289 - mean_squared_error: 29.4727 - mean_absolute_error: 3.8524
# Epoch 9935/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 37.6143 - root_mean_squared_error: 6.1330 - mean_squared_error: 37.6143 - mean_absolute_error: 4.2543
# Epoch 9936/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 44.8789 - root_mean_squared_error: 6.6992 - mean_squared_error: 44.8789 - mean_absolute_error: 4.5824
# Epoch 9937/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 43.0723 - root_mean_squared_error: 6.5630 - mean_squared_error: 43.0723 - mean_absolute_error: 4.5071
# Epoch 9938/10000
# 16/16 [==============================] - 0s 7ms/step - loss: 33.9940 - root_mean_squared_error: 5.8304 - mean_squared_error: 33.9940 - mean_absolute_error: 4.0662
# Epoch 9939/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 29.8795 - root_mean_squared_error: 5.4662 - mean_squared_error: 29.8795 - mean_absolute_error: 3.8981
# Epoch 9940/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 27.8583 - root_mean_squared_error: 5.2781 - mean_squared_error: 27.8583 - mean_absolute_error: 3.7734
# Epoch 9941/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 30.0214 - root_mean_squared_error: 5.4792 - mean_squared_error: 30.0214 - mean_absolute_error: 3.9473
# Epoch 9942/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 27.8500 - root_mean_squared_error: 5.2773 - mean_squared_error: 27.8500 - mean_absolute_error: 3.8187
# Epoch 9943/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 37.8805 - root_mean_squared_error: 6.1547 - mean_squared_error: 37.8805 - mean_absolute_error: 4.1393
# Epoch 9944/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 35.6765 - root_mean_squared_error: 5.9730 - mean_squared_error: 35.6765 - mean_absolute_error: 4.1337
# Epoch 9945/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 31.9680 - root_mean_squared_error: 5.6540 - mean_squared_error: 31.9680 - mean_absolute_error: 4.0589
# Epoch 9946/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 34.5810 - root_mean_squared_error: 5.8806 - mean_squared_error: 34.5810 - mean_absolute_error: 4.3171
# Epoch 9947/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 28.2509 - root_mean_squared_error: 5.3152 - mean_squared_error: 28.2509 - mean_absolute_error: 3.7956
# Epoch 9948/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 28.2758 - root_mean_squared_error: 5.3175 - mean_squared_error: 28.2758 - mean_absolute_error: 3.8362
# Epoch 9949/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 27.9812 - root_mean_squared_error: 5.2897 - mean_squared_error: 27.9812 - mean_absolute_error: 3.8248
# Epoch 9950/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 31.2159 - root_mean_squared_error: 5.5871 - mean_squared_error: 31.2159 - mean_absolute_error: 3.8801
# Epoch 9951/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 28.7462 - root_mean_squared_error: 5.3615 - mean_squared_error: 28.7462 - mean_absolute_error: 3.9503
# Epoch 9952/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 30.3375 - root_mean_squared_error: 5.5079 - mean_squared_error: 30.3375 - mean_absolute_error: 4.0000
# Epoch 9953/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 43.1001 - root_mean_squared_error: 6.5651 - mean_squared_error: 43.1001 - mean_absolute_error: 4.6318
# Epoch 9954/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 50.3883 - root_mean_squared_error: 7.0985 - mean_squared_error: 50.3883 - mean_absolute_error: 5.1623
# Epoch 9955/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 39.5040 - root_mean_squared_error: 6.2852 - mean_squared_error: 39.5040 - mean_absolute_error: 4.2975
# Epoch 9956/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 39.1070 - root_mean_squared_error: 6.2536 - mean_squared_error: 39.1070 - mean_absolute_error: 4.1958
# Epoch 9957/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 31.6719 - root_mean_squared_error: 5.6278 - mean_squared_error: 31.6719 - mean_absolute_error: 4.0325
# Epoch 9958/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 32.3842 - root_mean_squared_error: 5.6907 - mean_squared_error: 32.3842 - mean_absolute_error: 3.8876
# Epoch 9959/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 34.2501 - root_mean_squared_error: 5.8524 - mean_squared_error: 34.2501 - mean_absolute_error: 4.1659
# Epoch 9960/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 52.5577 - root_mean_squared_error: 7.2497 - mean_squared_error: 52.5577 - mean_absolute_error: 4.9733
# Epoch 9961/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 39.6571 - root_mean_squared_error: 6.2974 - mean_squared_error: 39.6571 - mean_absolute_error: 4.6696
# Epoch 9962/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 35.9184 - root_mean_squared_error: 5.9932 - mean_squared_error: 35.9184 - mean_absolute_error: 4.0955
# Epoch 9963/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 32.1208 - root_mean_squared_error: 5.6675 - mean_squared_error: 32.1208 - mean_absolute_error: 4.0812
# Epoch 9964/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 32.1739 - root_mean_squared_error: 5.6722 - mean_squared_error: 32.1739 - mean_absolute_error: 4.1127
# Epoch 9965/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 33.7903 - root_mean_squared_error: 5.8129 - mean_squared_error: 33.7903 - mean_absolute_error: 4.0617
# Epoch 9966/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 38.0613 - root_mean_squared_error: 6.1694 - mean_squared_error: 38.0613 - mean_absolute_error: 4.1750
# Epoch 9967/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 33.6653 - root_mean_squared_error: 5.8022 - mean_squared_error: 33.6653 - mean_absolute_error: 4.1437
# Epoch 9968/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 36.2565 - root_mean_squared_error: 6.0213 - mean_squared_error: 36.2565 - mean_absolute_error: 4.2252
# Epoch 9969/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 31.3576 - root_mean_squared_error: 5.5998 - mean_squared_error: 31.3576 - mean_absolute_error: 3.9177
# Epoch 9970/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 30.2659 - root_mean_squared_error: 5.5014 - mean_squared_error: 30.2659 - mean_absolute_error: 4.0368
# Epoch 9971/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 45.5987 - root_mean_squared_error: 6.7527 - mean_squared_error: 45.5987 - mean_absolute_error: 4.5795
# Epoch 9972/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 33.0972 - root_mean_squared_error: 5.7530 - mean_squared_error: 33.0972 - mean_absolute_error: 4.2906
# Epoch 9973/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 41.2860 - root_mean_squared_error: 6.4254 - mean_squared_error: 41.2860 - mean_absolute_error: 4.3463
# Epoch 9974/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 53.2820 - root_mean_squared_error: 7.2995 - mean_squared_error: 53.2820 - mean_absolute_error: 5.0385
# Epoch 9975/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 33.0178 - root_mean_squared_error: 5.7461 - mean_squared_error: 33.0178 - mean_absolute_error: 4.1422
# Epoch 9976/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 36.6129 - root_mean_squared_error: 6.0509 - mean_squared_error: 36.6129 - mean_absolute_error: 4.2542
# Epoch 9977/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 35.0714 - root_mean_squared_error: 5.9221 - mean_squared_error: 35.0714 - mean_absolute_error: 4.2384
# Epoch 9978/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 33.1112 - root_mean_squared_error: 5.7542 - mean_squared_error: 33.1112 - mean_absolute_error: 3.9237
# Epoch 9979/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 37.3507 - root_mean_squared_error: 6.1115 - mean_squared_error: 37.3507 - mean_absolute_error: 4.0715
# Epoch 9980/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 38.9908 - root_mean_squared_error: 6.2443 - mean_squared_error: 38.9908 - mean_absolute_error: 4.5137
# Epoch 9981/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 48.9814 - root_mean_squared_error: 6.9987 - mean_squared_error: 48.9814 - mean_absolute_error: 4.6590
# Epoch 9982/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 103.7018 - root_mean_squared_error: 10.1834 - mean_squared_error: 103.7018 - mean_absolute_error: 6.3489
# Epoch 9983/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 988386.7500 - root_mean_squared_error: 994.1764 - mean_squared_error: 988386.7500 - mean_absolute_error: 495.5087
# Epoch 9984/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 811898.6250 - root_mean_squared_error: 901.0542 - mean_squared_error: 811898.6250 - mean_absolute_error: 457.4913
# Epoch 9985/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 366028.0938 - root_mean_squared_error: 605.0026 - mean_squared_error: 366028.0938 - mean_absolute_error: 302.5135
# Epoch 9986/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 117569.2578 - root_mean_squared_error: 342.8837 - mean_squared_error: 117569.2578 - mean_absolute_error: 180.8431
# Epoch 9987/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 22980.1328 - root_mean_squared_error: 151.5920 - mean_squared_error: 22980.1328 - mean_absolute_error: 74.0495
# Epoch 9988/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 7289.8296 - root_mean_squared_error: 85.3805 - mean_squared_error: 7289.8296 - mean_absolute_error: 53.5887
# Epoch 9989/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 646.4916 - root_mean_squared_error: 25.4262 - mean_squared_error: 646.4916 - mean_absolute_error: 16.7176
# Epoch 9990/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 216.5579 - root_mean_squared_error: 14.7159 - mean_squared_error: 216.5579 - mean_absolute_error: 8.9716
# Epoch 9991/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 78.2593 - root_mean_squared_error: 8.8464 - mean_squared_error: 78.2593 - mean_absolute_error: 6.2071
# Epoch 9992/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 79.4150 - root_mean_squared_error: 8.9115 - mean_squared_error: 79.4150 - mean_absolute_error: 6.0155
# Epoch 9993/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 59.3770 - root_mean_squared_error: 7.7057 - mean_squared_error: 59.3770 - mean_absolute_error: 5.5795
# Epoch 9994/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 50.6247 - root_mean_squared_error: 7.1151 - mean_squared_error: 50.6247 - mean_absolute_error: 5.0140
# Epoch 9995/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 45.7352 - root_mean_squared_error: 6.7628 - mean_squared_error: 45.7352 - mean_absolute_error: 4.9128
# Epoch 9996/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 45.7973 - root_mean_squared_error: 6.7674 - mean_squared_error: 45.7973 - mean_absolute_error: 4.7434
# Epoch 9997/10000
# 16/16 [==============================] - 0s 4ms/step - loss: 44.9410 - root_mean_squared_error: 6.7038 - mean_squared_error: 44.9410 - mean_absolute_error: 4.8975
# Epoch 9998/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 42.7133 - root_mean_squared_error: 6.5355 - mean_squared_error: 42.7133 - mean_absolute_error: 4.7202
# Epoch 9999/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 41.6019 - root_mean_squared_error: 6.4500 - mean_squared_error: 41.6019 - mean_absolute_error: 4.6814
# Epoch 10000/10000
# 16/16 [==============================] - 0s 5ms/step - loss: 41.1908 - root_mean_squared_error: 6.4180 - mean_squared_error: 41.1908 - mean_absolute_error: 4.5648

# %%
predictions = model.predict(X_test)

# %%
model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 44.5291 - root_mean_squared_error: 6.6730 - mean_squared_error: 44.5291 - mean_absolute_error: 4.3477
# [44.52907180786133, 6.67301082611084, 44.52907180786133, 4.347742080688477]

# %%
model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 24.9200 - root_mean_squared_error: 4.9920 - mean_squared_error: 24.9200 - mean_absolute_error: 3.5903
# [24.919973373413086, 4.99199104309082, 24.919973373413086, 3.5903284549713135]

# %% [markdown]
# #### Split data frame into training and testing

# %%
# Testing data size in percent
test_size = 0.3

# Split into training and testing data
win_train, win_test = train_test_split(dfwin, test_size=test_size, random_state=42)
sta_train, sta_test = train_test_split(dfsta, test_size=test_size, random_state=42)
stb_train, stb_test = train_test_split(dfstb, test_size=test_size, random_state=42)

# Combine spacecraft datasets
train = pd.concat([win_train, sta_train, stb_train])
test = pd.concat([win_test, sta_test, stb_test])

# Save the index of the events, as appearing in the data frames, to a numpy array
win_train_ind = win_train.index.to_numpy()
win_test_ind  = win_test.index.to_numpy()
sta_train_ind = sta_train.index.to_numpy()
sta_test_ind  = sta_test.index.to_numpy()
stb_train_ind = stb_train.index.to_numpy()
stb_test_ind  = stb_test.index.to_numpy()

# Calculate indices for training and testing data frame
train_ind = train.index.to_numpy()
test_ind = test.index.to_numpy()

# Some useful stuff:
# train.info()
# train.describe()

# %% [markdown]
# #### Feature selection

# %%
# Select features
use_features = list(train.columns)
use_features.remove('Target')

# Bring data into shape for machine learning models
if len(use_features) == 1:
    X_train = np.array(train[use_features]).reshape(-1, 1)
    X_test = np.array(test[use_features]).reshape(-1, 1)
else:
    X_train = np.array(train[use_features])
    X_test = np.array(test[use_features])
    
y_train = np.array(train['Target']).reshape(-1, 1)
y_test = np.array(test['Target']).reshape(-1, 1)

# Use pickle to save training and testing data
fname = os.path.join(mfrdir, 'fh{:.0f}_train_test_data.p'.format(feature_hours))
pickle.dump([n_iwinind, n_istaind, n_istbind, 
             win_train_ind, win_test_ind, 
             sta_train_ind, sta_test_ind, 
             stb_train_ind, stb_test_ind, 
             train_ind, test_ind, 
             X_train, X_test, y_train, y_test, 
             feature_hours], open(fname, 'wb'))

# %% [markdown]
# #### Select algorithms for machine learning

# %%
# Define machine learning models
def get_models(models=dict()):
    models['lr'] = LinearRegression()
    models['lasso'] = Lasso()
    models['ridge'] = Ridge()
    models['en'] = ElasticNet()
    models['rfr'] = RandomForestRegressor()
    models['gbr'] = GradientBoostingRegressor()
 

    return models

# Fit model, evaluate it and get scores
def sklearn_predict(model, X, y):
    # fit the model
    model.fit(X, y)
    # prediction
    y_predict = model.predict(X)
    score, mean_score, std_score = evaluate_forecast(model, X, y, y_predict)
    return score, mean_score, std_score, y_predict

# Define scores
def evaluate_forecast(model, X, y, y_predict):
    scores = cross_val_score(model, X, y, scoring='neg_mean_squared_error', cv=5)
    score = np.sqrt(-scores)
    mean_score = score.mean()  # root mean squared error
    std_score = score.std()
    return score, mean_score, std_score

# %% [markdown]
# #### Test different machine learning algorithms

# %%
# Use pickle to load training and testing data
savepath_traintest ='fh{:.0f}_train_test_data.p'.format(feature_hours)
fname = 'mfr_predict/' + savepath_traintest
[n_iwinind, n_istaind, n_istbind, win_train_ind, win_test_ind, sta_train_ind, sta_test_ind, 
     stb_train_ind, stb_test_ind, train_ind, test_ind, 
     X_train, X_test, y_train, y_test, feature_hours] = pickle.load(open(fname, 'rb'))

# Get different machine learning models
models = get_models()

# Define seed to compare the results
np.random.seed(42)

mean_score = np.zeros(len(models))
std_score = np.zeros(len(models))
imod = 0

print("{:<10}{:<6}{:<6}".format("Model", "PCC", "MAE"))
for name, model in models.items():
    # fit model, evaluate and get scores
    score, mean_score[imod], std_score[imod], y_predict = sklearn_predict(model, X_train, y_train)
    # summarize scores
    ppmc = scipy.stats.pearsonr(np.squeeze(y_train), np.squeeze(y_predict))[0]
    mae = mean_absolute_error(np.squeeze(y_train), np.squeeze(y_predict))
    print("{:<10}{:6.2f}{:6.2f}".format(name, ppmc, mae))

# %% [markdown]
# #### Validation of machine learning models

# %%
# Validate machine learning model on test data
print("{:<10}{:<6}{:<6}".format("Model", "PCC", "RMSE"))
for name, model in models.items():
    y_pred1 = models[name].predict(X_test)
    mae1 = mean_absolute_error(np.squeeze(y_test), np.squeeze(y_pred1))
    cc1 = scipy.stats.pearsonr(np.squeeze(y_test), np.squeeze(y_pred1))[0]
    print("{:<10}{:6.2f}{:6.2f}".format(name, cc1, mae1))
# Out:
# Model     PCC   RMSE
# lr          0.32  4.80
# lasso       0.71  3.63
# ridge       0.30  4.91
# en          0.73  3.58
# rfr         0.69  3.20
# gbr         0.62  3.32

# %% [markdown]
# #### Optimising model hyperparameters

# %%
# Set to True when you want to redo the Hyperparameter tuning - takes a few minutes
# [ToDo] Need to check why the results are not improving with the tuning...
gridsearch = False

from sklearn.model_selection import RandomizedSearchCV

# %%
if gridsearch:
    gbr_param_grid = {'n_estimators': [100, 200, 300, 400],
                      'min_samples_split': [2, 3, 4, 5],
                      'min_samples_leaf': [1, 2, 3, 4],
                      'max_depth': [2, 3, 4, 5],
                      'learning_rate': [0.01, 0.1]}
    clf_gbr = GradientBoostingRegressor()
    clf = RandomizedSearchCV(clf_gbr, gbr_param_grid, n_iter=200, cv=3, verbose=1)
    cv_model = clf.fit(X_train, y_train)
    best_params_gbr = cv_model.best_params_
else:
    best_params_gbr = {'n_estimators': 400, 'min_samples_split': 5, 
                       'min_samples_leaf': 1, 'max_depth': 3, 'learning_rate': 0.1}
    
print(best_params_gbr)
models['gbr'] = GradientBoostingRegressor(**best_params_gbr)
score, _, _, y_predict_opt = sklearn_predict(models['gbr'], X_train, y_train)
# summarize scores
print("GBR Grid Search Hyperparameter Tuning results:")
ppmc = scipy.stats.pearsonr(np.squeeze(y_train), np.squeeze(y_predict_opt))[0]
mae = mean_absolute_error(np.squeeze(y_train), np.squeeze(y_predict_opt))
print("{:<10}{:6.2f}{:6.2f}".format('train', ppmc, mae))

y_pred1 = models['gbr'].predict(X_test)
mae1 = mean_absolute_error(np.squeeze(y_test), np.squeeze(y_pred1))
cc1 = scipy.stats.pearsonr(np.squeeze(y_test), np.squeeze(y_pred1))[0]
print("{:<10}{:6.2f}{:6.2f}".format('test', cc1, mae1))
# Out:
# {'n_estimators': 400, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_depth': 3, 'learning_rate': 0.1}
# GBR Grid Search Hyperparameter Tuning results:
# train       1.00  0.03
# test        0.67  3.36

# %%
if gridsearch:
    rfr_param_grid = {'n_estimators': [100, 200, 300, 400],
                      'min_samples_split': [2, 3, 4, 5],
                      'min_samples_leaf': [1, 2, 3, 4],
                      'max_depth': [2, 3, 4, 5]}
    rfr_clf = RandomForestRegressor()
    clf_rfr = RandomizedSearchCV(rfr_clf, rfr_param_grid, n_iter=200, cv=3, verbose=1)
    cv_model_rfr = clf_rfr.fit(X_train, y_train)
    best_params_rfr = cv_model_rfr.best_params_
else:
    best_params_rfr = {'n_estimators': 300, 'min_samples_split': 4, 
                       'min_samples_leaf': 1, 'max_depth': 5}
    
print(best_params_rfr)
models['rfr'] = RandomForestRegressor(**best_params_rfr)
score, _, _, y_predict_opt = sklearn_predict(models['rfr'], X_train, y_train)
# summarize scores
print("")
print("RFR Grid Search Hyperparameter Tuning Results:")
ppmc = scipy.stats.pearsonr(np.squeeze(y_train), np.squeeze(y_predict_opt))[0]
mae = mean_absolute_error(np.squeeze(y_train), np.squeeze(y_predict_opt))
print("{:<10}{:6.2f}{:6.2f}".format('train', ppmc, mae))

y_pred1 = models['rfr'].predict(X_test)
mae1 = mean_absolute_error(np.squeeze(y_test), np.squeeze(y_pred1))
cc1 = scipy.stats.pearsonr(np.squeeze(y_test), np.squeeze(y_pred1))[0]
print("{:<10}{:6.2f}{:6.2f}".format('test', cc1, mae1))
# Out:
# {'n_estimators': 300, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_depth': 5}
#
# RFR Grid Search Hyperparameter Tuning Results:
# train       0.93  2.06
# test        0.70  3.17

# %%
# Select best models according to scores
model1 = models['lr'] 
model2 = models['rfr'] 
model3 = models['gbr'] 

y_pred1 = model1.predict(X_test)
y_pred2 = model2.predict(X_test)
y_pred3 = model3.predict(X_test)

# %%
importances = model3.feature_importances_
indices = np.argsort(importances)
feat_imps_rfr = pd.Series(model2.feature_importances_, use_features).sort_values(ascending=False)[0:15]
feat_imps_gbr = pd.Series(model3.feature_importances_, use_features).sort_values(ascending=False)[0:15]

# Plot the feature importances of the forest
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))
feat_imps_rfr.plot(kind='bar', title="Feature importances in RFR", ax=ax1)
feat_imps_gbr.plot(kind='bar', title="Feature importances in GBR", ax=ax2)

plt.subplots_adjust(wspace=0.2)

# Possible method of interpretation for LR:
# https://scikit-learn.org/stable/auto_examples/inspection/plot_linear_model_coefficient_interpretation.html

for ax, ann in zip([ax1, ax2], ['a', 'b']):
    ax.text(.9, .9, ann, transform=ax.transAxes, fontsize=26, weight='bold')

argv3='feature_importance_minbz_{}h.pdf'.format(feature_hours)  
plt.savefig('plots/' + argv3, bbox_inches='tight')
plt.show()

# %%
# (n, 1) -- (n,)
y_test = np.squeeze(y_test)
y_pred1 = np.squeeze(y_pred1)
y_pred2 = np.squeeze(y_pred2)
y_pred3 = np.squeeze(y_pred3)
# (n,) -- (n, 1)
#y_pred1 = y_pred1.reshape(-1,1)

# %%
# Create scatter density plots for different models
from scipy.stats import gaussian_kde

fig, [(ax1,ax2),(ax3,ax4)] = plt.subplots(2, 2,figsize=(12,12))

x = y_test
y = y_pred1
xy = np.vstack([x,y])
z = gaussian_kde(xy)(xy)
idx = z.argsort()
x, y, z = x[idx], y[idx], z[idx]

ax1.scatter(x, y, c=z, s=50, edgecolor='')
ax1.set_xlim([2,-25])
ax1.set_ylim([2,-25])
ax1.set_aspect('equal', 'box')
ax1.text(-21, -2, 'LR', fontsize=18)
ax1.set_xlabel('min($B_{\mathrm{z}}$) observed [nT]', fontsize=14)
ax1.set_ylabel('min($B_{\mathrm{z}}$) predicted [nT]', fontsize=14)
ax1.plot([-100, 100],[-100, 100], ls=":")

x = y_test
y = y_pred2
xy = np.vstack([x,y])
z = gaussian_kde(xy)(xy)
idx = z.argsort()
x, y, z = x[idx], y[idx], z[idx]

ax2.scatter(x, y, c=z, s=50, edgecolor='')
ax2.set_xlim([2,-25])
ax2.set_ylim([2,-25])
ax2.set_aspect('equal', 'box')
ax2.text(-21, -2, 'RFR', fontsize=18)
ax2.set_xlabel('min($B_{\mathrm{z}}$) observed [nT]', fontsize=14)
ax2.set_ylabel('min($B_{\mathrm{z}}$) predicted [nT]', fontsize=14)
ax2.plot([-100, 100],[-100,100], ls=":")

x = y_test
y = y_pred3
xy = np.vstack([x,y])
z = gaussian_kde(xy)(xy)
idx = z.argsort()
x, y, z = x[idx], y[idx], z[idx]

ax3.plot([-100, 100],[-100, 100], ls=":")
ax3.scatter(x, y, c=z, s=50, edgecolor='')
ax3.set_xlim([2,-25])
ax3.set_ylim([2,-25])
ax3.set_aspect('equal', 'box')
ax3.text(-21, -2, 'GBR', fontsize=18)
ax3.set_xlabel('min($B_{\mathrm{z}}$) observed [nT]', fontsize=14)
ax3.set_ylabel('min($B_{\mathrm{z}}$) predicted [nT]', fontsize=14)
ax4.boxplot([np.abs(y_test-y_pred1),np.abs(y_test-y_pred2),np.abs(y_test-y_pred3)])
ax4.set_ylim([-1,30])

plt.xticks([1, 2, 3], ['LR', 'RFR', 'GBR'], fontsize=14)
asp = np.diff(ax4.get_xlim())[0] / np.diff(ax4.get_ylim())[0]
ax4.set_aspect(asp)
ax4.set_ylabel('Absolute Errors [nT]', fontsize=14)

plt.subplots_adjust(wspace=0.25)
for ax, ann in zip([ax1, ax2, ax3, ax4], ['a', 'b', 'c', 'd']):
    ax.text(.05, .9, ann, transform=ax.transAxes, fontsize=20, weight='bold')

argv3='scatter_plot_minbz_{}h.pdf'.format(feature_hours)  
plt.savefig('plots/' + argv3, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Point-to-point comparison metrics

# %%
import sklearn

def meanError(mod, obs):
    me = obs.mean() - mod.mean()
    return me

def meanAbsoluteError(mod, obs):
    mae = (np.abs(obs - mod)).mean()
    return mae

def meanSquaredError(mod, obs):
    mse = ((obs - mod) ** 2).mean()
    return mse

def rootMeanSquaredError(mod, obs):
    rmse = np.sqrt(((obs - mod) ** 2).mean())
    return rmse

def skillScore(mod, obs):
    refDF = np.full(obs.shape,obs.mean())
    mseRef = ((obs - refDF) ** 2).mean()
    mseMod = ((obs - mod) ** 2).mean()
    ss = 1 - (mseMod/mseRef)
    return ss

# 1. Compute point-to-point comparison metrics 
obs = y_test
me = meanError(y_pred1, obs)
mae = meanAbsoluteError(y_pred1, obs)
mse = meanSquaredError(y_pred1, obs)
rmse = rootMeanSquaredError(y_pred1, obs)
ss = skillScore(y_pred1, obs)
pcc = scipy.stats.pearsonr(np.squeeze(obs), np.squeeze(y_pred1))[0]

# Print results
print(), print('(LR):', feature_hours)
print('Mean = {:.2f}'.format(np.mean(y_pred1)))
print('Std  = {:.2f}'.format(np.std(y_pred1)))
print('ME   = {:.2f}'.format(me))
print('MAE  = {:.2f}, sklearn: {:.2f}'.format(mae, sklearn.metrics.mean_absolute_error(obs, y_pred1)))
print('MSE  = {:.2f}, sklearn: {:.2f}'.format(mse, sklearn.metrics.mean_squared_error(obs, y_pred1)))
print('RMSE = {:.2f}, sklearn: {:.2f}'.format(rmse, np.sqrt(sklearn.metrics.mean_squared_error(obs, y_pred1))))
print('SS   = {:.2f}'.format(ss,))
print('PCC  = {:.2f}'.format(pcc,))

me = meanError(y_pred2, obs)
mae = meanAbsoluteError(y_pred2, obs)
mse = meanSquaredError(y_pred2, obs)
rmse = rootMeanSquaredError(y_pred2, obs)
ss = skillScore(y_pred2, obs)
pcc = scipy.stats.pearsonr(np.squeeze(obs), np.squeeze(y_pred2))[0]

# Print results
print(), print('(RFR):', feature_hours)
print('Mean = {:.2f}'.format(np.mean(y_pred2)))
print('Std  = {:.2f}'.format(np.std(y_pred2)))
print('ME   = {:.2f}'.format(me))
print('MAE  = {:.2f}, sklearn: {:.2f}'.format(mae, sklearn.metrics.mean_absolute_error(obs, y_pred2)))
print('MSE  = {:.2f}, sklearn: {:.2f}'.format(mse, sklearn.metrics.mean_squared_error(obs, y_pred2)))
print('RMSE = {:.2f}, sklearn: {:.2f}'.format(rmse, np.sqrt(sklearn.metrics.mean_squared_error(obs, y_pred2))))
print('SS   = {:.2f}'.format(ss,))
print('PCC  = {:.2f}'.format(pcc,))

me = meanError(y_pred3, obs)
mae = meanAbsoluteError(y_pred3, obs)
mse = meanSquaredError(y_pred3, obs)
rmse = rootMeanSquaredError(y_pred3, obs)
ss = skillScore(y_pred3, obs)
pcc = scipy.stats.pearsonr(np.squeeze(obs), np.squeeze(y_pred3))[0]

# Print results
print(), print('(GBR):', feature_hours)
print('Mean = {:.2f}'.format(np.mean(y_pred3)))
print('Std  = {:.2f}'.format(np.std(y_pred3)))
print('ME   = {:.2f}'.format(me))
print('MAE  = {:.2f}, sklearn: {:.2f}'.format(mae, sklearn.metrics.mean_absolute_error(obs, y_pred3)))
print('MSE  = {:.2f}, sklearn: {:.2f}'.format(mse, sklearn.metrics.mean_squared_error(obs, y_pred3)))
print('RMSE = {:.2f}, sklearn: {:.2f}'.format(rmse, np.sqrt(sklearn.metrics.mean_squared_error(obs, y_pred3))))
print('SS   = {:.2f}'.format(ss,))
print('PCC  = {:.2f}'.format(pcc,))
print()
print('Mean Obs. = {:.2f}'.format(np.mean(obs)))
print('Std. Obs.  = {:.2f}'.format(np.std(obs)))
# Out:
# (LR): 4
# Mean = -9.67
# Std  = 12.26
# ME   = 0.61
# MAE  = 4.80, sklearn: 4.80
# MSE  = 143.36, sklearn: 143.36
# RMSE = 11.97, sklearn: 11.97
# SS   = -2.24
# PCC  = 0.32
#
# (RFR): 4
# Mean = -9.46
# Std  = 4.50
# ME   = 0.40
# MAE  = 3.17, sklearn: 3.17
# MSE  = 22.66, sklearn: 22.66
# RMSE = 4.76, sklearn: 4.76
# SS   = 0.49
# PCC  = 0.70
#
# (GBR): 4
# Mean = -9.67
# Std  = 4.87
# ME   = 0.61
# MAE  = 3.36, sklearn: 3.36
# MSE  = 24.77, sklearn: 24.77
# RMSE = 4.98, sklearn: 4.98
# SS   = 0.44
# PCC  = 0.67
#
# Mean Obs. = -9.06
# Std. Obs.  = 6.65

# %% [markdown]
# #### Binary metrics

# %%
# 2. Binary Metrics 
def contingencyTable(mod, obs, threshold):
    eventMod = np.full(mod.shape,0)
    eventMod[mod > threshold] = 1
    eventObs = np.full(obs.shape,0)
    eventObs[obs > threshold] = 1
    
    tp = sum(eventMod + eventObs == 2)
    fp = sum(eventMod) - tp
    fn = sum(eventObs) - tp
    tn = sum(eventMod + eventObs == 0)
    return [tp, fp, fn, tn]

def truePostiveRate(ct):
    tpr = ct[0]/(ct[0] + ct[2])
    return tpr

def falsePostiveRate(ct):
    fpr = ct[1]/(ct[1] + ct[3])
    return fpr

def threatScore(ct):
    ts = ct[0]/(ct[0] + ct[1] + ct[2])
    return ts

def trueSkillStatistics(ct):
    tss = ct[0]/(ct[0] + ct[2]) - ct[1]/(ct[1] + ct[3])
    return tss
    
def bias(ct):
    bs = (ct[0] + ct[1])/(ct[0] + ct[2])
    return bs

# 2. Compute binary metrics
threshold = -10
ct = contingencyTable(y_pred1,obs,threshold)
tpr = truePostiveRate(ct)
fpr = falsePostiveRate(ct)
ts  = threatScore(ct)
tss = trueSkillStatistics(ct)
bs  = bias(ct)

# Print results
print(), print('(LR):')
print(ct)
print('TH   = {:.2f}'.format(threshold,))
print('TPR  = {:.2f}'.format(tpr,))
print('FPR  = {:.2f}'.format(fpr,))
print('TS   = {:.2f}'.format(ts,))
print('TSS  = {:.2f}'.format(tss,))
print('Bias = {:.2f}'.format(bs,))

ct = contingencyTable(y_pred2,obs,threshold)
tpr = truePostiveRate(ct)
fpr = falsePostiveRate(ct)
ts  = threatScore(ct)
tss = trueSkillStatistics(ct)
bs  = bias(ct)

# Print results
print(), print('(RFR):')
print(ct)
print('TH   = {:.2f}'.format(threshold,))
print('TPR  = {:.2f}'.format(tpr,))
print('FPR  = {:.2f}'.format(fpr,))
print('TS   = {:.2f}'.format(ts,))
print('TSS  = {:.2f}'.format(tss,))
print('Bias = {:.2f}'.format(bs,))

ct = contingencyTable(y_pred3,obs,threshold)
tpr = truePostiveRate(ct)
fpr = falsePostiveRate(ct)
ts  = threatScore(ct)
tss = trueSkillStatistics(ct)
bs  = bias(ct)

# Print results
print(), print('(GBR):')
print(ct)
print('TH   = {:.2f}'.format(threshold,))
print('TPR  = {:.2f}'.format(tpr,))
print('FPR  = {:.2f}'.format(fpr,))
print('TS   = {:.2f}'.format(ts,))
print('TSS  = {:.2f}'.format(tss,))
print('Bias = {:.2f}'.format(bs,))
# Out:
# (LR):
# [54, 17, 16, 18]
# TH   = -10.00
# TPR  = 0.77
# FPR  = 0.49
# TS   = 0.62
# TSS  = 0.29
# Bias = 1.01
#
# (RFR):
# [59, 20, 11, 15]
# TH   = -10.00
# TPR  = 0.84
# FPR  = 0.57
# TS   = 0.66
# TSS  = 0.27
# Bias = 1.13
#
# (GBR):
# [55, 16, 15, 19]
# TH   = -10.00
# TPR  = 0.79
# FPR  = 0.46
# TS   = 0.64
# TSS  = 0.33
# Bias = 1.01

# %%
'''
# Compute ROC curve
array = 0
threshold = -12
ct = contingencyTable(y_pred1,obs,threshold)
tpr = truePostiveRate(ct)
fpr = falsePostiveRate(ct)
ts  = threatScore(ct)
tss = trueSkillStatistics(ct)
bs  = bias(ct)

idx = 0
tpr_arr = np.zeros(300)
fpr_arr = np.zeros(300) 
for threshold in np.arange(-25, 0,0.1):
    ct = contingencyTable(y_pred1,obs,threshold)
    tpr_arr[idx] = truePostiveRate(ct)
    fpr_arr[idx] = falsePostiveRate(ct)
    idx = idx + 1
   
array = np.array([tpr_arr, fpr_arr])
test = np.sort(array, axis=1)

plt.subplots(1, figsize=(5,5))
plt.title('Receiver Operating Characteristic - GBR')
plt.plot(test[1,:], test[0,:])
plt.plot([0, 1], ls="-.")
plt.plot([0, 0], [1, 0] , c=".8"), plt.plot([1, 1] , c=".8")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
'''
# Out:
# '\n# Compute ROC curve\narray = 0\nthreshold = -12\nct = contingencyTable(y_pred1,obs,threshold)\ntpr = truePostiveRate(ct)\nfpr = falsePostiveRate(ct)\nts  = threatScore(ct)\ntss = trueSkillStatistics(ct)\nbs  = bias(ct)\n\nidx = 0\ntpr_arr = np.zeros(300)\nfpr_arr = np.zeros(300) \nfor threshold in np.arange(-25, 0,0.1):\n    ct = contingencyTable(y_pred1,obs,threshold)\n    tpr_arr[idx] = truePostiveRate(ct)\n    fpr_arr[idx] = falsePostiveRate(ct)\n    idx = idx + 1\n   \narray = np.array([tpr_arr, fpr_arr])\ntest = np.sort(array, axis=1)\n\nplt.subplots(1, figsize=(5,5))\nplt.title(\'Receiver Operating Characteristic - GBR\')\nplt.plot(test[1,:], test[0,:])\nplt.plot([0, 1], ls="-.")\nplt.plot([0, 0], [1, 0] , c=".8"), plt.plot([1, 1] , c=".8")\nplt.ylabel(\'True Positive Rate\')\nplt.xlabel(\'False Positive Rate\')\nplt.show()\n'

# %% [markdown]
# ## 3. Real-world Applications

# %%
from matplotlib.dates import DateFormatter

def plot_all_mos(sat, n_ind, start_range, end_range, satname, varstr='min'):

    nrows = end_range - start_range
    plt.figure(figsize=(15, 4 * nrows))

    for iEv in range(start_range, end_range):
        ind = n_ind[test_ind[iEv]] # be careful with this!

        buffer_win = 12.
        istart = np.where(sat['time'] >= icme_start_time_num[ind] - buffer_win/24.)[0][0]
        iend = np.where(sat['time'] >= mo_end_time_num[ind] + buffer_win/24.)[0][0]

        icmestart = np.where(sat['time'] >= icme_start_time_num[ind])[0][0]
        mostart = np.where(sat['time'] >= mo_start_time_num[ind])[0][0]
        mostart_fh = np.where(sat['time'] >= mo_start_time_num[ind] + feature_hours/24.)[0][0]   # !
        moend = np.where(sat['time'] >= mo_end_time_num[ind])[0][0]

        larr = len(sat['time'][int(mostart):int(moend)])
        predVal = np.zeros(larr)
        yObs = np.zeros(larr)
        predVal[:] = y_pred[iEv]
        yObs[:] = y_test[iEv]

        test_larr = len(sat['time'][int(mostart):int(mostart_fh)])
        X_test_plot = np.zeros(test_larr)
        X_test_plot = X_test[iEv]

        plt.subplot(nrows, 1, iEv - start_range + 1)
        plt.plot(sat['time'][int(istart):int(iend)], sat['bz'][int(istart):int(iend)])
        target_str = r"B$_{z}$"
        plt.plot(sat['time'][int(mostart):int(moend)], predVal, 'r-', label=r'{}({}) prediction in {}'.format(varstr, target_str, satname))
        plt.plot(sat['time'][int(mostart):int(moend)], yObs, 'b-', label=r'{}({}) observation in {}'.format(varstr, target_str, satname))
        plt.axvline(x=sat['time'][int(icmestart)], color='g', linestyle='--')
        plt.axvline(x=sat['time'][int(mostart)], color='r', linestyle='--')
        plt.axvline(x=sat['time'][int(mostart_fh)], color='g', linestyle='--')   # !
        plt.axvline(x=sat['time'][int(moend)], color='r', linestyle='--')
        plt.xlabel('Time')
        plt.ylabel('B$_{z}$ [nT]')
        plt.xlim((sat['time'][istart], sat['time'][iend]))
        plt.legend(numpoints=1, ncol=2, loc=1)
        ax = plt.gca()
        ax.text(.01, .1, 'Absolute Error = {:.2f} nT'.format(np.abs(yObs[iEv]-predVal[iEv])), transform=ax.transAxes, fontsize=16)
        ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d\n%H:%M'))    # !
        
    argv3='{}_plot.pdf'.format(satname)  
    plt.savefig('plots/' + argv3, bbox_inches='tight')
    plt.show()

# %%
#Example in Figure 1:
y_pred = y_pred3
plot_all_mos(win, n_iwinind, 17, 20, 'Wind')

# %%
y_pred = y_pred2
start_range, end_range = 0, np.size(win_test_ind)
plot_all_mos(win, n_iwinind, 0, 5, 'Wind')
#start_range, end_range = len(win_test_ind), len(win_test_ind) + len(sta_test_ind)
#plot_all_mos(sta, n_istaind, start_range, end_range, 'STEREO-A')
#start_range, end_range = len(win_test_ind) + len(sta_test_ind), len(test_ind)
#plot_all_mos(stb, n_istbind, start_range, end_range, 'STEREO-B')
